# %% [markdown]
# <img style="float: center; width: 100%" src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png">
# <p style="margin-bottom:2cm;"></p>
#
# <center>
#     <H1> Merjenje uporabnikov: psihofiziološki signali </H1>
#
#
#
# <br><br>
#     <H3> Andrej Košir, Lucami, FE </H3>
#     <H4> Kontakt: andrej.kosir@fe.uni-lj.si </H4>
#     <H4> ZOOM https://uni-lj-si.zoom.us/j/8638167479  </H4>
# </center>
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 1 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:left;"> Cilji, ponudba </div>
# </div>
#
#
# ## Cilji
#
# - spoznati osnovne psihofiziološke signale in njihovo uporabnost pri spremljanju uporabnikov
# - spoznati izbrane senzorje psihofizioloških isgnalov
# - spoznati osnovne tehnike modeliranja psihofizioloških signalov s strojnim učenjem
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 2 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Cilji, ponudba </div>
# </div>
#
#
# ## Vsebina
#
# ### 1. Fiziologija in signali uporabnika
#
# ■ Fiziologija človeka in psihofiziološki signali $\large{*}$
#
# ■ Socialni signali uporabnika $\large{*}$
#
# ■ Ocenjevanje socialnih signalov uporabnika $\large{*}$
#
# ■ Čustva: merjenje signalov
#
# ■ Čustva: merjenje afektivnega stanja, sistem kodiranja obraznih aktivnosti FACS (Facial action coding system)
#
# ■ Čustva: merjenje afektivnega stanja, orodje Noldus Face reader
#
# ■ Čustva: določanje afektivnega stanja, orodja
#
# ■ Kognitivna obremenitev: merjenje signalov
#
# ■ Pozornost: merjenje signalov
#
# ■ Stres: merjenje signalov
#
#
# ### 2. Merjenje psiho-fizioloških odzivov in senzorji
#
# ■ Merjenje očesa
#
# ■ Merjenje elektrodermalne aktivnosti
#
# ■ Merjenje srca
#
# ■ Merjenje možganskih aktivnosti
#
# ■ Merjenje dihanja
#
# ■ Merjenje gest in poze
#
# ■ Merjenje uporabnika: živeči laboratorij (living lab)
#
# ■ Živeči laboratorij: seznam senzorjev
#
# ■ Zaključek
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 3 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Fiziologija človeka in psihofiziološki signali
#
#
# #### Def. Psihofiziologija je znanstvena disciplina, ki raziskuje odnos med fiziologijo in kognitivnimi procesi.
#
# #### Def. Socialni signali uporabnika so merljivi signali uporabnikov, ki so povezani ali podajajo njegova fiziološka stanja.
#
# #### Pomembna spoznanja:
#  - psihofiziološki signali so neposredno merljivi
#  - merijo hitre spremembe v človeku - uporabniku
#  - Obstaja povezava med psihofiziološkimi signali in kognitivnimi procesi
#
#
#
# #### Pomembni fiziološki signali za komunikacijo
#  - Signali oči: velikost zenice, pogled, utripanje, ...
#  - Signali srca: HR, ...
#  - Signali kože: elektrodermalna aktivnost
#
#
#
# #### Pomembne ocene iz teh meritev:
#  - Afektivna in čustvena stanja
#  - kognitivna obremenitev
#  - stres
#  - pozornost
#  - angažiranost
#  - multimedijska izpostavljenost
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Socialni signali uporabnika
#
# #### Def.: Socialni signali so vse kar ostane od komunikacije med človekom in njegovim sogovornikom (človekom ali strojem) ko izločimo pomen govora. Ostane barva glasu, ritem govora, izraz na obrazu, geste itd. Uporabljamo tudi izraz "neverbalna komunikacija".
#
# #### Def.: Izraz sogovornik uporabljamo za vse komunikacijske entitete - človeka, stroj, storitev.
#
# <img style="float: center; width: 65%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/SoialSignals-Concept_SLO.png">
#
# <br>
#
# ##### Primeri socialnih signalov so:
# - zadovoljstvo
# - radovednost
# - oklevanje
# - ...
#
# <br>
#
# **Socialni signali** se s **časom spreminjajo**, lahko s precej različno hitrostjo.
#
#
# ##### Uporabnost
#
# Socialni signali so uporabni za
# - **komunikacijo v realnem času**: pomembna obogatitev vsebine
# - **prilagajanje uporabniku**: razumevanje stanja uporabnika v realnem čas
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 5 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Ocenjevanje socialnih signalov uporabnika
#
#
# ### Pristopi s strojnim in statističnim učenjem
#
# Cilj ocenjevanja - dve možnosti:
# 1. Ocena kvantitativne vrednosti socialnega signala na danem intervalu, npr. na $[1, 5]$;
# 2. Klasifikacija socialnega signala v izbrane razrede, npr _{nizko, srednje, visoko}_
#
#
# ### Dva koraka
#
# 1. Določanje značilk
# 2. Ocena / klasifikacija - strojno in statistično učenje
#
# 2.1. Ocenjevanje socianega signala - modeli:
# - linearna regresija
# - nelinearni modeli
# - modeli napovedovanja časovnih vrst
#
#
# 2.2. Klasifikacija socailanih signalov - strojno učenje:
# - globoko učenje (ne zahteva določanja značilk)
# - Metoda podpornih vektorjev
# - Odločitvena drevesa
#
#
#
# Koncept ocenjevanja je na voljo na spodnji sliki.
#
# <figure>
#   <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/SocSigsFromPsySigs.png" width="60%">
#   <figcaption>Vir: Shu: A Review of Emotion Recognition Using Physiological Signals, Sensors, 2018.</figcaption>
# </figure>
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 6 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Čustva: merjenje signalov
#
#
# #### Signali za merjenje čustev
#
#
# Za komunikacije merljivi signali z dovolj nizko intruzivnostjo:
# 1. Sledenje oči:
# - Velikost zenice
# - vzorci pogleda
# 2. Elektrodermalna aktivnost kože
# - afektivno stanje vzburjenje
# 3. Srčni utrip
# - hitrost srčnega utripa in vzorci
#
#
#
# <br><br>
# <figure>
#   <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/HumanPsychoFiziologyEmotions.png" width="80%">
#   <figcaption>Vir: Shu: A Review of Emotion Recognition Using Physiological Signals, Sensors, 2018.</figcaption>
# </figure>
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 7 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ## ■ Čustva: merjenje afektivnega stanja, sistem kodiranja obraznih aktivnosti FACS (Facial action coding system)
#
# Anatom Carl-Herman Hjortsjö je razvil sistem za kodiranje obraznih aktivnosti.
#
#
# <img style="float: center; width: 40%;" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/HeadNeckMuscle.jpg">
#
#
#
# Antropologa <b>Paul Ekman in Wallace V. Friesen</b> sta te aktisnoti povezala s čustvenimi stanji. Gre za natančno preslikavo aktivnosti v čustvena stanja
#
#
# <table style="width:30%">
#   <tr>
#     <td style="text-align:left"><b>Aktivnosti</b></td>
#     <td style="text-align:left"><b>Čustveno stanje</b></td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 4+5+7+23 </td>
#     <td style="text-align:left"> Jeza </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> R12A+R14A </td>
#     <td style="text-align:left"> Zadovoljstvo </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 9+15+16 </td>
#     <td style="text-align:left"> Gnus </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 1+2+4+5+7+20+26 </td>
#     <td style="text-align:left"> Strah </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 6+12 </td>
#     <td style="text-align:left"> Sreča </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 1+4+15 </td>
#     <td style="text-align:left"> Žalost </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> 1+2+5B+26 </td>
#     <td style="text-align:left"> Presenečenje </td>
#   </tr>
# </table>
#
# <br>
#
# Obstaja <b>tečaj kodiranja</b>, kjer se naučiš sledenja teh kod.
#
# Sistem FACS je tudi osnova za računalniške programe, ki na podlagi analize videa razpoznavajo afektivno stanje (VAD) in izbrano čustveno stanje, npr. [Noldus Face Reader](ttps://www.noldus.com/human-behavior-research/products/facereader).
#
# <br>
#
# _Literatura_ : Ekman P. Facial Signs of Emotional Experience, Journal of Personality and Social Psychology, 1980.
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 8 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ## ■ Čustva: merjenje afektivnega stanja, knjižnica Deepface in orodje Noldus Face reader
#
#
# Python knjižnica [DeepFace](https://pypi.org/project/deepface/).
#
# Plačljivo orodje ponudnika [Noldus](https://www.noldus.com/human-behavior-research).
#
#
#
# Izgled uporabniškega vmesnika:
# <img style="float: center; width: 40%;" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/NoldusFaceReader_GUI.jpg">
#
#
#
# Osnovni pristop:
# - Prileganje 3D mreže na obraz, kar daje dobro robusnost
# - Identifikacija Ekmanovih točk (FACS)
#
# <img style="float: center; width: 40%;" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/NoldusFaceReader_Mesh.jpg">
#
#
#
# ##### Funkcionalnosti:
# - merjenje afektivnega stanja v VAD prostoru, realno časovno merjenje A in D;
# - preslikava v čustveni prostor - cirkumpleksni model
# - časovno zvezne koordinate 49 obraznih točk
# - časovno zvezni grafi stanj
# - izvoz podaktov v datoteko
#
#
# ##### Prednosti:
# - delujoč sistem
# - veliko študij ovrednotenja suešnosti
#
#
# ##### Slabosti:
# - položaj gledalca pred kamero mora biti v precej ozkih okvirjih, ki onemogočajo širše scenarije testiranj - testna oseba nujno sedi za mizo
# - nekatere študije so pokazale, da so rezultati merjenja vsaj občasno precej napačni
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 9 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ## ■ Čustva: merjenje afektivnega stanja, uspešnosti modalnosti v merjenju afektivnega stanja
#
# Spodnja tabela podaja seznam uspešnosti modalnosti. Lastnost "nadzor" pomeni koliko lahko uporabnik to modalnost zavestno nadzira (upravlja).
#
#
# <table style="width:95%">
#   <tr>
#     <td style="text-align:left"><b>Vir</b></td>
#     <td style="text-align:left"><b>A</b></td>
#     <td style="text-align:left"><b>V</b></td>
#     <td style="text-align:left"><b>Samonadzor</b></td>
#     <td style="text-align:left"><b>Prednosti</b></td>
#     <td style="text-align:left"><b>Slabosti</b></td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> Avdio signal</td>
#     <td style="text-align:left"> +++ </td>
#     <td style="text-align:left"> ++ </td>
#     <td style="text-align:left"> Visok </td>
#     <td style="text-align:left"> Zanesljivo, enostavno </td>
#     <td style="text-align:left"> Malokrat na voljo </td>
#   </tr>
#   <tr>
#     <td style="text-align:left"> Jezik (pisan) </td>
#     <td style="text-align:left"> ++ </td>
#     <td style="text-align:left"> +++ </td>
#     <td style="text-align:left"> Visok </td>
#     <td style="text-align:left"> Vezan na vsebino govora </td>
#     <td style="text-align:left"> Razpoznava ni najboljša. </td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Vizualni signal </td>
#     <td style="text-align:left">++ </td>
#     <td style="text-align:left">+++ </td>
#     <td style="text-align:left">Nizek </td>
#     <td style="text-align:left">Navadno na voljo </td>
#     <td style="text-align:left">Šibek opis znakov</td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Psihosociološli </td>
#     <td style="text-align:left">+ </td>
#     <td style="text-align:left">+ </td>
#     <td style="text-align:left">Odsoten </td>
#     <td style="text-align:left">Robusno </td>
#     <td style="text-align:left">Intruzivno </td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Možganski signali  </td>
#     <td style="text-align:left">+ </td>
#     <td style="text-align:left">++ </td>
#     <td style="text-align:left">Odsoten </td>
#     <td style="text-align:left">Visok potencial </td>
#     <td style="text-align:left">Intruzivno </td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Taktilni sigali </td>
#     <td style="text-align:left">++ </td>
#     <td style="text-align:left">+ </td>
#     <td style="text-align:left">nizek </td>
#     <td style="text-align:left">Robusten, neintruzivno </td>
#     <td style="text-align:left">Pogosto ni na voljo. </td>
#   </tr>
#   <caption>Tabela: Uspešnost razpoznave afektivnega stanja VAD prostora po posameznih izvorih informacij </caption>
# </table>
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Kognitivna obremenitev: merjenje signalov
#
#
# #### Signali za merjenje
# 1. Sledenje oči:
# - velikost zenice
# - vzorci pogleda
# 2. Srčni utrip
# - variabilnost srčnega utripa
# 3. Elektrodermalna aktivnost (EDA)
# - večja EDA pomeni večjo kognitivno obremenitev
#
#
#
# <br><br>
# <figure>
#   <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/PsySignalsCognitiveLoad.jpg" width="50%">
#   <figcaption>Vir: Ahmad in dr: A framework to estimate cognitive load using physiological data, Personal and Ubiquitous Computing, 2020.<br>
#       Vir: Johanseen: Psychophysiologic measures of cognitive load in physician team leaders
# during trauma resuscitation, Computers in human behaviour, 2020.
#     </figcaption>
# </figure>
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 12 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Pozornost: merjenje signalov
#
#
# #### Signali za merjenje pozornosti:
# 1. Sledenje oči
# - vzorci pogleda
# - velikost zenice
# 2. Klikotok:
# - vzorci premikov mišk
# - vzorci tipkanja
# 3. Razpoznava obrazov:
# - Na osnovi "Facial action coding system (FACS) je mogoče razpoznavati pozornost
#
#
# <br><br>
# <figure>
#   <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/PsySignalsAttention.png" width="40%">
#   <figcaption>Vir: Gamboa: Attention Classification Based on Biosignals during Standard
# Cognitive Tasks for Occupational Domains, Computers, 2022.</figcaption>
# </figure>
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 13 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Stres: merjenje signalov
#
#
# #### Signali za merjenje stresa
#
# 1. Srčni utrip:
# - znižan Heart rate variability (HRV) pomeni povečan stres
# 2. Elektrodermlna aktivnost
# - večja prevodnost kože pomeni večji stre
# 3. Dihanje
# - hitro dihanje ali spreminjajoči se vzorci dihanja ponijo povečan stres
# 4. Razpoznava obrazov:
# - Na osnovi "Facial action coding system (FACS) je mogoče razpoznati povečanje stresa
# 5. Analiza govora
# - spremembe v tonu in višini glasu pomenijo spremembo nivoja stresa
#
# <br><br>
# <figure>
#   <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/HumanPsychoFiziologyStress.png" width="40%">
#   <figcaption>Vir: Giannakakis: Review on Psychological Stress Detection Using Biosignals, IEEE TRANSACTIONS ON AFFECTIVE COMPUTING, 2022.</figcaption>
# </figure>
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 14 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  2. Merjenje psiho-fizioloških odzivov
#
# ■ Merjenje očesa
#
# ■ Merjenje elektrodermalne aktivnosti
#
# ■ Merjenje srca
#
# ■ Merjenje možganskih aktivnosti
#
# ■ Merjenje dihanja
#
# ■ Merjenje gest in poze
#
# ■ Merjenje uporabnika: živeči laboratorij (living lab)
#
# ■ Živeči laboratorij: seznam senzorjev
#
# ■ Zaključek
#
#
# _Literatura:_ Lee J. D. , Wickens C. D., Liu Y., and Boyle L. N., Designing for people: an introduction to human factors engineering, 3rd edition. Charleston, SC: CreateSpace, 2017.
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 15 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje očesa
#
# #### Merimo
# - velikost zenice: kognitivna obremenitev
# - pogled (lokacija pogleda): pozornost, ...
# - dogodki: sekade, fiksacije, ..
#
#
# #### Izbrane lastnosti
# - sekade in fiksacije
#
#
# #### Senzorji, orodja
#  - Tobii: https://www.tobii.com/, analitična orodja v oblaku
#  - PupilLabs: https://pupil-labs.com/, analitična orodja v oblaku
#
#
# #### Primer signala
#
# ##### Velikost zenice (ob času $0$ začnemo z nalogo "n-back")
# <img width="60%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/PupilDiameter_change.png">
#
#
# ##### Kaskade in fiksacije
# <img width="40%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/EyeFixations.jpg">
#
#
#
# <br><br>
# _Literatura_ : Spletna stran Wikipedia https://en.wikipedia.org/wiki/Saccade  <br>
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 16 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje elektrodermalne aktivnosti
#
# #### Merimo
# - impedanco kože pri različnih frekvencah
#
#
# #### Analiza
# - fazna komponenta (angl. Phasic Skin Conductance Response (SCR)): hitro spreminjajoč se signal, ki je odvisen od dražljaja
# - tonična komponenta (Tonic Skin Conductance Level (SCL)): počasi spreminjajoč signal in neprekinjen
#
# Zanima nas fazna komponenta, tonično izločimo za natančnejšo oceno fazne komponente.
#
#
# #### Orodja
#  - Python neurokit: https://neurokit2.readthedocs.io/en/latest/index.html
#
#
# #### Primeri signalov
#
# Elektrodermalna aktivnost in dekompozicija na fazno in tonično komponento.
# <img width="80%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/EDA_Decomposition.png">
#
#
#
#
# <br><br>
# _Literatura_ : Spletna stran Wikipedia https://en.wikipedia.org/wiki/Electrodermal_activity  <br>
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 17 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje srca
#
#
# #### Merimo
#  - električni signal srčne mišice (elektro kardiogram)
#
#
# #### Analiza
#  - P, Q, S in T valovi: štiri faze krčenja in raztezanja srčne mišice
#
#
# #### Orodja
#  - Python neurokit: https://neurokit2.readthedocs.io/en/latest/index.html
#
#
# #### Primeri signala
#
# Točke P in Q.
# <img width="60%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/Heart_PQpoints.png"/>
#
#
#
# <br><br>
# _Literatura_ : Spletna stran Wikipedia https://en.wikipedia.org/wiki/Electrocardiography  <br>
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 18 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje dihanja
#
# #### Merimo
# - premikanje prsnega koša
#
#
# #### Analiza
# - Spremenljivost hitrosti dihanja (Respiratory Rate Variability (RRV)):
# - Frekvenčna analiza RRV
# - Poincarejev diagram
#
# #### Orodja
# Python neurokit: https://neurokit2.readthedocs.io/en/latest/index.html
#
#
#
# #### Primeri signalov
#
# Signal dihanja:
# <img width="80%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/Respiration_rate.png">
#
#
#
# <br><br>
# _Literatura_ : Spletna stran Wikipedia https://en.wikipedia.org/wiki/Respiratory_rate  <br>
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 19 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje gest in poze
#
#
# #### Merimo
#  - z RGB in IR kamerami merimo del telesa ali celotno telo ter določamo skeleton.
#
#
# #### Analiza
#  - sledenje gibanja, obnašanj
#
#
# #### Primer isignalov
# Skeleton uporabnika
# <img width="40%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/KinectSkeleton.png">
#
#
# <br><br>
# _Literatura_ : Spletna stran Wikipedia https://en.wikipedia.org/wiki/Electroencephalography  <br>
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 21 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Merjenje uporabnika: živeči laboratorij (living lab)
#
# <br><br>
#
# <img width="90%" src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/LivingLab.png">
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 22 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: psihofiziološki signali </div>
# </div>
#
# ##  ■ Živeči laboratorij: seznam senzorjev
#
# <br><be>
#
# <table style="width:80%">
#   <tr>
#     <th style="text-align:left">Merjeni signal</th>
#     <th style="text-align:left">Ocenjen signal</th>
#     <th style="text-align:left">Senzor</th>
#   </tr>
#   <tr>
#     <td style="text-align:left">Video</td>
#     <td style="text-align:left">Afektivno, čustveno stanje </td>
#     <td style="text-align:left"><img width="40%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/CameraRGB.png"></td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Elektrodermalna aktivnost</td>
#     <td style="text-align:left">Stres</td>
#     <td style="text-align:left"><img width="40%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/EmpaticaEmbracePlus.png"></td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Elektrodermalna aktivnost</td>
#     <td style="text-align:left">Stres</td>
#     <td style="text-align:left"><img width="40%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/ShimmerSensor.png"></td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Velikost zenice</td>
#     <td style="text-align:left">Kognitivna obremenitev</td>
#     <td style="text-align:left"><img width="60%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/TobiiGlasses.png"></td>
#   </tr>
#     <tr>
#     <td style="text-align:left">Velikost zenice</td>
#     <td style="text-align:left">Kognitivna obremenitev</td>
#     <td style="text-align:left"><img width="80%"  src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/SensorTobiiEyeTrackerNano.jpg" width="60%"></td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Geste in poza</td>
#     <td style="text-align:left">Upravljanje UI, Socialni signali</td>
#     <td style="text-align:left"><img width="40%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/Kinect3.png"></td>
#   </tr>
#   <tr>
#     <td style="text-align:left">Geste in poza</td>
#     <td style="text-align:left">Upravljanje UI, Socialni signali</td>
#     <td style="text-align:left"><img width="40%"  src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/CameraLuxonisOAK.png"></td>
#   </tr>
# </table>
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%; text-align: right; font-weight:bold; font-size:1.2em;"> 23 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;text-align:right;"> Merjenje uporabnikov: psihofiziološki signali  </div>
# </div>
#
#
# # ■ Zaključek
#
#
# - Psihofiziološki senzorji omogočajo oceno izbranih socialnih signalov blisu realnega časa
# - Bistvena je nadležnost senzorja: primernost za realne aplikacije
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 24 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">
