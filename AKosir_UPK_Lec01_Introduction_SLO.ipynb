# %% [markdown]
# <img src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png" style="float: center; width: 100%;">
# <p style="margin-bottom: 2cm;"></p>
#
# <center>
#     <h1>  1. Uvod v uporabniku prilagojeno komunikacijo </h1>
#
#
# <br>
#     <h3> Andrej Košir, Lucami, FE </h3>
#     <h4> Kontakt: prof. dr. Andrej Košir, andrej.kosir@lucami.fe.uni-lj.si, skype=akosir_sid </h4>
# </center>
#
#
# <p style="margin-bottom: 2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> Cilji, učni izidi </div>
# </div>
#
# ### Cilji
# - spoznati področje uporabniku prilagojene komunikacije
# - umestiti uporabniku prilagojene komunikacije v multimedijo
#
#
# ### Učni izidi
# - razumeti cilje uporabniku prilagojene komunikacije
# - razumeti osnovne mehanizme prilagajanja
# - spoznati osnovne pojme uporabniku prilagojene komunikacije
#
#
#
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 1 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;">  1. 1. Kako se je uporabnik znašel v središču - zgodovina </div>
# </div>
#
# ## 1. 1. Uporabnik in prilagajanje
#
# ■ Primer prilagojene storitve: Priporočilni sistemi
#
# ■ Kako se je uporabnik znašel v središču - zgodovina
#
# ■ Delitev uporabnikove pozornosti
#
# ■ Uporabnik in minimalna kraja pozornosti
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 2 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Primer prilagojene storitve: Priporočilni sistemi
#
#
# - Jedro inteligence: napovedovanje uporabnikovih odločitev, ki jih nato uporabimo za prilagoditev:
#     - Vsebine
#     - Storitve – vmesnika, poteka, ... .
#
#
# - Domene priporočanja
#     - Vsebine: knjige, filmi, hoteli potovanja
#     - Prilagajanje UI
#
#
# - Vrste algoritmov priporočilnih sistemov:
#     - Vsebinski in skupinski
#     - Hibridni
#
#
# - Pogovorni priporočilni sistemi
#     - več korakov komunikacije
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 3 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;">  1. 1. Uporabnik in prilagajanje </div>
# </div>
#
# ## ■ Kako se je uporabnik znašel v središču - zgodovina
#
# ### (Tele)komunikacijski sistem
#
# - Podatkovno skladišče, komunikacijski kanal, terminal, uporabnik, skupina uporabnikov.
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/CommunicationSystem_SLO.png" style="float: right; width: 40%;">
#
#
# ### Zgodovina
#
# - Prve rešitve
#     - storitev
#     - uporabniških vmesnikov
# so bile izdelane za profesionalne uporabnike.
#
#
# - Kasneje so se pridružili neprofesionalni uporabniki, ki so danes v veliki večini.
# - Strojna oprema (prenosni kanali, spomin, procesorji) so presegli potrebe za shranjevanje in prenos podatkov. So na voljo za vključevanje novih skupin uporabnikov.
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <center><font>
#       <h3> Kako te vire uporabiti v dobro uporabnika? </h3>
# </font>
# </center>
#
#
#
# <p style="margin-bottom: 8cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.1. Uporabnik in prilagajanje  </div>
# </div>
#
# ## ■ Delitev uporabnikove pozornosti
#
#
# <h5>
# Def.: Pozornost je proces s katerim aktivno spremljamo omejeno količino vseh dražljajevin informacij, ki jih zaznamo s svojimi čutili, jih imamo shranjene v spominu ali jih pridobimo z ostalimi kognitivnimi procesi. (Sternberg, 2006)
# </h5>
# V poenostavljenem jeziku je pozornost postopek, pri katerem "se z mislimi osredotočamo na trenutno dejavnost".
#
# <h5>
# Def.: Deljena pozornost nam omogoča, da istočasno opravljamo več nalog oz. da lahko svojo pozornost osredotočamo na več dejavnikov hkrati, svojo pozornost pa nadzorovano lahko preusmerjamo od enega dejavnika/opravila k drugemu.
# </h5>
# V našem okviru nas zanima prehajanje pozornosti med storitvijo (MM vsebino) in upravljanjem storitve.
#
# <h5>
# Def.: Kraja pozornosti je pojav pri komunikaciji med uporabnikom in storitvijo, pri čemer je delež deljene pozornosti za upravljanje storitve nepotrebno velik.
# </h5>
# Izraz nepotrebno velik pomeni, da obstaja realna tehnološka možnost, da je delež pozornosti za upravljanje storitve manjši.
#
# ##### Merjenje
#
# * Izven realnega časa: vprašalniki
# * V realnem času: sledenje oči
#
# <br><br>
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/AttentionTheft_AttentionSplit.png" style="float: center; width: 80%;">
#
#
# Literaura: Sternberg, J.R. (2006). Cognitive psychology (4th Ed.). Belmont: Thomson Wodsworth.
#
#
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 5 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.1. Uporabnik in prilagajanje  </div>
# </div>
#
# ## ■ Uporabnik in minimalna kraja pozornosti
#
#
# <h5>
# Def.: Kvaliteta storitve (Quality of service, QoS) je opis ali merjenje celotne učinkovitosti storitve.
# </h5>
#
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/AttentionTheft_QoS.png" style="float: center; width: 80%;">
#
#
#
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 6 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## 1.2. Mehanizmi prilagajanja
#
# ■ Celotna slika prilagajanja
#
# ■ Kontekst uporabnika
#
# ■ Določanje konteksta uporabnika
#
# ■ Osebnost in personalizacija
#
# ■ Razpoloženje, čustva
#
# ■ Socialni signali
#
# ■ Neizkoriščena možnost: socialna inteligenca storitev
#
# ■ Pomemben segment prilagajanja: komunikacija in večmodalnost
#
# ■ Prilagajanje in odločitve uporabnika: modeli človeških odločitev
#
# ■ Implementacija prilagajanja: strojno učenje
#
#
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 7 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Celotna slika prilagajanja
#
# <figure>
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/UserAdaptation-Mechanisms.png" style="float: center; width: 100%;">
# <figcaption> Slika: Celoten proces prilahajanja storitve. </figcaption>
# </figure>
#
# ### Bistvena vprašanja pri implementaciji prilagajanja
# - (1): Katere podatke o kontekstu (situaciji) spremljati? $\to$ **Kontekst**
# - (2): Kako uporabiti podatke socialnega omrežja uporabnika? $\to$ **Kontekst**
# - (3): Katere podatke o zgodovini aktivnosti beležiti? $\to$ **Model uporabnika**
# - (4): Kateri senzorji so uporabni? $\to$ **Kontekst, čustva, razpoloženje**
# - (5): Kako modelirati uporabnika? $\to$ **Model uporabnika**
# - (6): Kako model uporabiti v inteligenci - Kako prilagoditi storitev in vmesnik? $\to$ **Mehanizmi prilagajanja**
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 8 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2 Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Kontekst uporabnika
#
#
# <h5>
# Def.: Kontekst je opis tistih vidikov situacije uporabnika, ki so relevantni za uporabnikove preference in odločitve glede same vsebine storitve.
# </h5>
#
# - Kaj je kontekst v komunikacijskem sistemu
#     - Kar vpliva na izvedbo komunikacije
#     - Med drugim: čas v dnevu, dan, vreme, čustveno stanje, socialno stanje, ...
#
#
# - Formalno ima kontekst tri dimenzije:
#     - Čas
#     - Prostor
#     - Aktvnost, <br>
#   ki imajo drevesno strukturo v smislu hierahičnega dodajanja detajlov.
#
#
# - Človekova komunikacija je vsebinsko in protokolno odvisna od konteksta:
#     - Kontekst vpliva na želje in na učinke
#     - Kontekst vpliva na potek odločanja
#
#
# - Testna množica Ldos-CoMoDa: uporablja več kot 80 skupin po svetu
#     - Izbor filmov
#     - 12 kontekstnih spremenljivk
#     - Ocena osebnosti v VAD prostoru
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 9 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2 Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Določanje konteksta uporabnika
#
# Kako določimo kontekst?
#
# Vir podatkov:
# - Internet stvari (IoT)
# - senzorji: pametni telefon, pametni dom, avto, ...
# - socialna omrežja, ...
#
#
# Algoritmi / procedure:
# - razčlenjevanje IoT podatkov
# - analiza senzorskih podatkov
# - analiza velikih podatkov
#
#
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/UserContext.png" style="float: center; width: 80%;">
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 10 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Osebnost in personalizacija
#
#
# ##### Def.: Osebnost je karekterističen nabor obnašanj, kognicije in čustvenih vzorcev. Tvori osebne lastnosti posameznika.
#
#
# ##### Def.: Personalizacija: storitev upošteva uporabnikove specifične lastnosti kot so osebnost in stališča
#
#
#
# **Modeli osebnosti: **
# - obstaja več modelov osebnosti, najbolj znan je model velikih 5 (angl. Big5);
# - osebnost uporabnika - kako je izmerimo: izdelan psihološki konstrukt (vprašalnik in navodila za prevod odgovorov v ocenjene dimenzije);
#
#
# **Prostor Big5: **
# - Sprejemljivost;
# - Ekstravertnost;
# - Odprtost;
# - Vestnost;
# - Nevroticizem;
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/Big5Space_ENG.png" style="float: center; width: 30%;">
#
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ##  ■ Razpoloženje, čustva, sentiment
#
# Osebnost se ne spreminja ali se spreminja zelo počasi, razpoloženje in čustva se spreminjata hitreje
#
# #### Razpoloženje: Nima posebnega opisa niti natančne definicije. Nekakšno "povprečje čustev"
#
# **Afektivni prostor VAD** (angl. Valence, Arousal, Dominance)
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/SpaceVAD_ANG.png" style="float: center; width: 30%;">
#
#
#
# **Prostori čustev**
# - obstaja več opisov in definicij
# - primer: Plutchnikovo kolo
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/EmotionsPlutchikWheel.png" style="float: center; width: 25%;">
#
#
#
#
#
#
# - Vprašanja
#     - Katera čustva inducirajo posamezne vsebine/storitve?
#     - Kako ta čustva vplivajo na odločitve?
#
#
# - Problem realnega časa
#     - Hitrost spreminjanja
#         - Osebnosti: v letih
#         - Razpoloženja: v minutah
#         - Čustev: manj kot v sekundi
#
# - Računski modeli
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 12 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Socialni signali
#
# - Socialni signali
#     - Vse razen govora
#     - Vgrajena lastnost človeka: "Karkoli ima oči in usta, angažira socialne signale“
#
# - Problem opisa v okviru merljivih signalov
#
#
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/SoialSignals-Concept_SLO.png" style="float: center; width: 80%;">
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 13 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Neizkoriščena možnost: socialna inteligenca storitev
#
# Naprava / storitev / komunikator je socialno inteligenten če:
# 1. Razpoznava in razume socialne signale sogovornika
# 2. Te signale inteligentno uporabi pri
#  - storitvi in
#  - komunikaciji
# 3. Izraža socialne signale
#
# V praksi glede na trenutno stopnjo razvoja za socialno inteligentno storitev priznamo tudi storitev, ki zmore le točki 1. in 2.
#
#
#
# <br><br>
# Kako **uporabiti znanje o uporabniku** tako, da
# - Izboljšamo storitev
# - Olajšamo uporabo – izboljšamo uporabniški vmesnik in s tem uporabniško izkušnjo
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 14 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Pomemben segment prilagajanja: komunikacija in večmodalnost
#
# Večmodalnost vmesnikov – komuniciramo preko
#  - Vida (81%), sluha, drugih čutil
#  - Nova senzorika: vlažnost kože, srčni utrip, dihanje, gibanje oči, obrazne točke, ...
#
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/HCI_modalities_ENG.png" style="float: center; width: 40%;">
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 15 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ## ■ Prilagajanje in odločitve uporabnika: modeli človeških odločitev
#
#
#
# - **Prilagajanje sledi ali celo predvideva človeške odločitve**: če storitev pravilno predvidi glasbo, ki jo nameravate poslušat, vam jo predlaga in prilagodi jakost igranja;
#
#
# - Modeli glede na področje uporabe;
#
#
# - Primer modeliranja človeškega odločanja: Teorija planiranega obnašanja (angl. Theory of planned behaviour)
#
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/AjzenModel_ENGL.png" style="float: center; width: 50%;">
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 16 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.2. Mehanizmi prilagajanja </div>
# </div>
#
# ##  ■ Implementacija prilagajanja: strojno učenje
#
#
#
# - Kaj je **model uporabnika**? To je zapis njegovih lastnosti v različnih oblikah:
#     - preteklo obnašanje
#     - mehanizem njegovega odločanja
#     - ...
#
#
# - Klasični pristopi multivariantne statistike in strojnega učenja
#     - Modeli napovedovanja
#     - Modeli klasifikacije in razvrščanja
#
#
# - Kako pri modelu uporabnika upoštevati
#     - Njegove situacije – kontekst
#     - Osebnosti, razpoloženja, čustev
#     - Specifične mehanizme odločanja
#     - Naravnega načina komunikacije
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 17 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.4 Kriteriji in mere uspešnosti </div>
# </div>
#
# ## 1.3 Kriteriji in mere uspešnosti
#
# - Uporabnost storitve: **brez uporabne vrednosti prilagajanje nima smisla**
# - Prilagajanje: glavni kriterij je visoka funkcionalnost ob minimalna kraja pozornosti
# - ne gradimo nadomestka za človeško bližino!
#
#
#
# - **ključno** domensko odvisne mere uspešnosti:
#     - sistem prilagajanja ne gradimo le na računalniških merah uspešnosti, ampak tudi na učinkih na realno življenje
#     - precej zapostavljeno področje v raziskovanju
#
#
#
# - Problem **dolgoročnih** učinkov
#     - izjemno kompleksne razmere z velikim številom faktorjev
#     - longitudinalne upoirabniške študije so težko izvedljive
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 18 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.4 Povezana raziskovalna področja in prilagajanje uporabnikov </div>
# </div>
#
# ## 1.4 Povezana raziskovalna področja in prilagajanje uporabnikov
#
# ■ Psihologija
#
# ■ Oblikovanje
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 19 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.4 Povezana raziskovalna področja in prilagajanje uporabnikov </div>
# </div>
#
# ## ■  Psihologija
#
# Kaj nam nudi psihologija:
# #### Konstrukte:
# - osebnost ipd
# - posebne metrike
#
# #### Računske modele:
# - računski modeli čustev
#
#
# #### Metodološke prisotpe k izdelavi novih kosntruktov in metrik
# - kakko načrtati in izvesti postopke za definicijo npr. oklevanja
#
#
# #### Pristope k zajemu podatkov o uporabniku
# - anotiranje
# - samoporočanje
# - think-aloud
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 20 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.4 Povezana raziskovalna področja in prilagajanje uporabnikov </div>
# </div>
#
# ## ■ Oblikovanje
#
#
# Oblikovanje uporabniških vmesnikov (grafičnih, haptičnih, ...) je bistvenega pomena.
#
#
# V tem predmetu jih ne pokrivamo, le umestimo.
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 21 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.5 Etični vidiki </div>
# </div>
#
# ## 1.5 Etični vidiki
#
#  ■ Jedro etike podatkov: ali uporabnik razume uporabo njegovih podatkov
#
# ■ Možnosti zlorab in rešitve
#
# ■ Kaj prispeva k kvaliteti življenja?
#
# ■ Kaj prispeva k kvaliteti življenja?
#
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 22 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Etični vidiki </div>
# </div>
#
# ## ■ Jedro etike podatkov: ali uporabnik razume uporabo njegovih podatkov
#
# <h4>
# Def: Etika je filozofski nauk o nravnosti, o dobrem in zlu; utemeljevanje moralnosti. Vključuje sistematizacijo, obrambo in priporočila za pravilno ravnanje.
# </h4>
#
#
# - Ključ: **ali uporabnik razume** kaj se dogaja z njegovimi podatki (=podatki o njim)?
#
# - Tehnologija ni več etično nevtralna
#     - Preproste tehnologije so bile
#     - Nove tehnologije niso več etično nevtralne
#
#
# - Primeri zlorab
#     - NetMob: identifikacija, zelo preprost algoritem.
#
#
#
# - Problem: uporabniki ne razumemo in/ali jih ne zanima kaj se vse da z zbranimi podatki doseči
#
#
# - ZDA:  Klik gumba [I agree] ne šteje več
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 23 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.5 Etični vidiki </div>
# </div>
#
# ## ■ Možnosti zlorab in rešitve
#
#
# Možnosti zlorab npr. zabeležeih socialnih signalov je neizmerno
# - Zaposlovanje
# - Zavarovalništvo
# - Socialna omrežja, …
#
#
# Rešitev: **Varnost in zasebnost v načrtu** (angl. security/privacy by design)
# - Nov izziv, ki zahteve spremembe v celem sistemu
# - Zahteva dodatno inovativnost
# - Specifično po domenah uporabe
#
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 24 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.5 Etični vidiki </div>
# </div>
#
# ## ■ Kaj prispeva k kvaliteti življenja?
#
# Kaj res prispeva k kvaliteti življenja?
# - Knjiga _Eli Pariser: The Filter Bubble: How the New Personalized Web Is Changing What We Read and How We Think_
# - Priporočilni sistem za hrano
# - Ravnovesje med sledenjem uporabnikovih želja in planiranim spremembam obnašanja
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 25 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Izbrani razvojni in raziskovalni izivi </div>
# </div>
#
# ## 1.7 Izbrani razvojni in raziskovalni izivi
#
# ■ Eksperimenti v realnem okolju
#
# ■ Zajem podatkov o uporabniku
#
# ■ Učinkovite realne aplikacije
#
# ■ Etika
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 26 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Izbrani razvojni in raziskovalni izivi </div>
# </div>
#
# ## ■ Eksperimenti v realnem okolju
#
#
# Izvajanje eksperimentov v realnem okolju
# - Problem konteksta uporabnika
# - Problem izmenjave vrednosti (angl. Value exchange) in nadzora na eksperimentom
# - Variabilnost v realnem okolju raste in preseže velikost učinka (angl. Effect size)
# - Zahtevni načrti poskusov. Modeli izračunljivosti.
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/UserExperimentsChallenge_SLO.png" style="float: center; width: 80%;">
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 27 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Izbrani razvojni in raziskovalni izivi </div>
# </div>
#
# ## ■ Neinvaziven zajem podatkov o uporabniku
#
#
# Novi načini zajema podatkov o uporabniku
# - Nujno za realne mere učinkovitosti
# - Psihološki vprašalniki ne ustrezajo v tem okolju
# - Vzorčenje izkušnje kot primer novega načina zajema
#
# <img src="https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/UserDataAcq_Challenge_SLO.png" style="float: center; width: 80%;">
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 28 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Izbrani razvojni in raziskovalni izivi </div>
# </div>
#
# ## ■ Učinkovite realne aplikacije
#
#
# Rešitve za konkretne aplikacije in skupine uporabnikov
# - Poznavanje domene komunikacija
# - Nove kombinacije zajem podatkov – prilagoditev storitve
#
#
# Uporaba socialnih signalov:
# - Identifikacija pojavnosti socialnih signalov: npr. oklevanje = {počasen gib roke, ...}
# - Identifikacija povezav izbranih socialnih signalov z odločitvami uporabnika
# - Katere socialne signala inducira uporabniški vmesnik?
#
#
# Uprabe neposrednih komunikacijskih kanalov z možgani
#
#
#
# Varnost in zasebnost v načrtu (angl. Security / Privacy by design)
# - Dodatna inovativnost in napor
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 29 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display: flex; font-weight: bold; font-size: 0.9em;">
# <div style="flex: 1; width: 50%;"> 1. Uvod v uporabniku prilagojeno komunikacijo </div>
# <div style="flex: 1; width: 50%; text-align: right;"> 1.6 Izbrani razvojni in raziskovalni izivi </div>
# </div>
#
# ## ■ Etika
#
#
# - prepoved tehnologije ni rešitev, rešitev so prilagojene tehnološke rešitve: omejitve glede etičnih rešitev za podatke so enakovredne tehnolčoškim omejitvam
#
#
# - zakonsko omejevanje dokler ni rešitev za varnost podatkov:
#     - če ni rešitve za varovanje podatkov, tehnologija ne gre v rabo
#     - pravni problem je večji od tehnološkega: čas v Google teče drugače kot v parlamentih
#
#
# <p style="margin-bottom: 2cm;"></p>
# <div style="width: 100%; text-align: right; font-weight: bold; font-size: 1.2em;"> 30 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">
