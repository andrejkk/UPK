# %% [markdown]
# <img style="float: center; width: 100%" src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png">
# <p style="margin-bottom:2cm;"></p>
#
# <center>
#     <H1> Implementacija in evalvacija eksperimenta </H1>
#
#
#
# <br><br>
#     <H3> Andrej Košir, Lucami, FE </H3>
#     <H4> Kontakt: prof. dr. Andrej Košir, andrej.kosir@fe.uni-lj.si, </H4>
#     <H4> ZOOM https://uni-lj-si.zoom.us/j/97654707084 </H4>
# </center>
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 1 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Eksperiment </div>
# <div style="flex:1;width:50%;text-align:right;"> Cilji, ponudba </div>
# </div>
#
#
# ## Cilj
#
# - razumeti načrt eksperimenta
# - izkusiti merjenje in testiranje kot testna oseba
# - razumeti evalvacijo eksperimenta
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 2 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.Uvod </div>
# </div>
#
#
# # 1. Načrt eksperimenta
#
# 1. Raziskovalno vprašanje: ali je na podlagi fiziologije ...
# 2. Načrt eksperimentalne naloge
#     - naloga: delo z aplikacijo za rekreativni šport
#     - izbor dveh aplikacij za primerjavo: Strava in Garmin
#     - implementacija eksperimenta:
# 2. Eksperimentalni načrt:
#     - kontroliran faktor: uporabniški vmesnik ali samoporočanje uporabnika
#     - moteči faktorji: spol, izkušnje s sorodnjmi aplikacijami
#     - merjenja odziva uporabnika: Nasa TLX, UEQ
# 3. Randomizacija
#     - Vrstni red uporabniških vmesnikov
#     - Spol?
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 3 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.Uvod </div>
# </div>
#
#
# # 2. Koraki uzvedbe eksperimenta
#
# 1. Pojasnila, formalno soglasje za udeležbo
# 2. Montaža senzorjev, zagon merilne aplikacije
# 3. Demografski vprašalnik
# 4. Izvedba naloge na 1. vmesniku
# 5. Samoporočanje: Nasa TLX, UEQ
# 6. Izvedba naloge na 2. vmesniku
# 7. Samoporočanje: Nasa TLX, UEQ
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 3 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1. 1. Umestitev optimizacije v TK </div>
# </div>
#
# # 3. Obdelava signalov
#
# - Amazon AWS ...
# - splines ...
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1. 1. Umestitev optimizacije v TK </div>
# </div>
#
# # 4. Analiza rezultatov: merske karakterisitke
#
# Veljavnost sledi iz eksperimentalno potrjenih eksperimentov
#
# Zanesljivost: za vsak instrument posebej, za vsako dimenzijo posebej
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
# Merske karakteristike Nasa TLX: zanesljivost =============

# Load data

# Estimate Cronbach alpha

# %%
# Merske karakteristike UEQ: zanesljivost

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1. 1. Umestitev optimizacije v TK </div>
# </div>
#
# # 5. Analiza rezultatov: Statistično testiranje
#
# Raziskovalno vprašanje "Ali ..." prevedemo na tri specifična raziskovalna vprašanja:
#
# RQ1: Ali ...
#
# RQ2: Ali ...
#
# RQ3: Ali ...
#
# Na vsako posebej odgovorimo s statističnim testiranjem hipotez, pri čemer:
# - oblikujemo ničelno hipotezo $H_0=[\text{sdsd}]$
# - glede na 1. tip spremenljivk in 2. porazdelitev podatkov izberemo najmočnejši statistični test, ki ustreza zahtevam: Mann-Whitney
# - izvedemo test: pridobimo p-vrednost
# - glede na stopnjo tveganja $\alpha=0.05$ odgovorimo na raziskovalno vprašanje
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
# Hypothese testing

# Load data

# Test distributions

# Implement significance test

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Strojno učenje </div>
# <div style="flex:1;width:50%;text-align:right;"> 1. 1. Umestitev optimizacije v TK </div>
# </div>
#
# # 6. Analiza rezultatov: Interpretacija rezultatov
#
# Glede na dobljene p-vrednosti testov zanačilnosti, odgovorimo na raziskovalna vprašanja:
#
# RQ1: DA
#
# RQ2:
#
# RQ3:
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">
