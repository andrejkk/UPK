# %% [markdown]
# <img src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png" style="float: center; width: 100%"/>
#
#
# <p style="margin-bottom:2cm;"></p>
# <center>
# <h1>4. Measurement of users</h1>
# <br/><br/>
# <h3>Andrej Košir, Lucami, Fe</h3>
# <h4>Contact: andrej.kosir@fe.uni-lj.si</h4>
# <h4>Zoom https://uni-lj-si.zoom.us/J/8638167479</h4>
# </center>
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">1</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;">Measurement of users</div>
# <div style="flex:1;width:50%;text-align:right;">Goals</div>
# </div>
#
# ## goals of the chapter
#
# - to learn the problem of measuring users
# - to get to know:
# - Measurement with questionnaires
# - constructs
# - Measurement with psychophysiological signals
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">2</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;">4. Measurement of users</div>
# <div style="flex:1;width:50%;text-align:right;">Content</div>
# </div>
#
# ## chapters
#
# ### 1. Measurement of users: instruments and constructs
#
#
# ### 1.1. Selected Instruments - Questions and Constructs
#
# ■ Introduction: Why psychological constructs in technology?$\Large{*}$
#
# ■ What is an instrument and what construct $\Large{*}$
#
# ■ Selected constructs interact with (smart) systems
#
# ■ Usability: System usability SUS $\Large{*}$
#
# ■ Usability (Usability): Umux Interaction Umux $\Large{*}$
#
# ■ Personality Measurement: Big 5 (Big5) $\Large{*}$
#
# ■ mood measurement: Panas $\Large{*}$
#
# ■ Measurement of engagement: ues $\Large{*}$
#
# ■ Measuring an emotional response: Sam $\Large{*}$
#
# ■ Measuring immersion: FSS $\Large{*}$
#
# ■ Measuring short -term multimedia exposure to ads: MMAES $\Large{*}$
#
# ■ User experience: UEQ $\Large{*}$
#
# ■ load load: NASA TLX, instrument $\Large{*}$
#
# ■ Measuring the quality of the two talk: Suisq $\Large{*}$
#
# ■ to the use of instruments and constructs
#
#
# ### 1.2. Calculation of Metrics of performance - Constructing Dimensions, Instrument
#
# ■ Introduction and example SUISQ
#
# ■ weights of the factor matrix define Construct $\Large{*}$
#
# ■ Calculate the points of construct or rock $\Large{*}$
#
#
# #### 1.3. Of the measurement characteristics
#
# ■ Problem of questionnaires and measurement characteristics $\Large{*}$
#
# ■ Validity $\Large{*}$
#
# ■ Reliability $\Large{*}$
#
#
#
# ### 2. Measurement of users: psychophysiological signals
#
# ### 2.1.Physiology and user signals
#
# ■ Human Physiology and Psychophysiological Signals $\Large{*}$
#
# ■ User's social signals $\Large{*}$
#
# ■ Assessing the social signals of the user $\Large{*}$
#
# ■ Emotions: Signal measurement
#
# ■ Emotions: Measurement
#
# ■ Emotions: Affective Measurement, Deepface Library, tool Noldus Face Reader
#
# ■ Emotions: Measurement of affective state, tools
#
# ■ Cognitive load: Measurement of signals
#
# ■ Attention: Signal measurement
#
# ■ Stress: Measurement of signals
#
#
#
# ### 2.2.Measuring psycho-physical responses and sensors
#
# ■ Measurement of the eye
#
# ■ Measuring electrodermal activity
#
# ■ Measurement of the heart
#
# ■ Measuring brain activity
#
# ■ Measuring breathing
#
# ■ Measuring gesture and poses
#
# ■ Measurement of user: Living Lab (Living Lab)
#
# ■ Living Laboratory: Sensor List
#
# ■ Conclusion
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">3</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>
