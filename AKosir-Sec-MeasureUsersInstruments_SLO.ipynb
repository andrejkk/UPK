# %% [markdown]
# <img style="float: center; width: 100%" src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png">
# <p style="margin-bottom:2cm;"></p>
#
# <center>
#     <H1> Merjenje uporabnikov - instrumenti in konstrukti </H1>
#
#
#
# <br><br>
#     <H3> Andrej Košir, Lucami, FE </H3>
#     <H4> Kontakt: andrej.kosir@fe.uni-lj.si </H4>
#     <H4> ZOOM https://uni-lj-si.zoom.us/j/8638167479  </H4>
# </center>
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 1 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov: instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> Cilji, ponudba </div>
# </div>
#
#
# ## Cilji
#
# - Cilji
#     - seznaniti se s problematiko merjenja uporabnikov z instrumenti (vprašalniki)
#     - spoznati in razumeti instrument in konstrukt
#     - spoznati pomembne vprašalnike
#     - spoznati vodila za korektno uporabo in interpretacijo
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 2 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti</div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1. Izbrani instrumenti - vprašalniki in konstrukti  </div>
# </div>
#
#
# # 1.1. Izbrani instrumenti - vprašalniki in konstrukti
#
#
# ■ Uvod: Zakaj psihološki konstrukti v tehnologiji? $\large{*}$
#
# ■ Kaj je instrument in kaj konstrukt $\large{*}$
#
# ■ Izbrani konstrukti v interakciji s (pametnimi) sistemi
#
# ■ Uporabnost (Usability): sistemska uporabnost SUS $\large{*}$
#
# ■ Uporabnost (Usability): Uporabnost interakcija UMUX $\large{*}$
#
# ■ Merjenje osebnosti: velikih 5 (Big5) $\large{*}$
#
# ■ Merjenje razpoloženja: PANAS $\large{*}$
#
# ■ Merjenje angažiranosti: UES $\large{*}$
#
# ■ Merjenje čustvenega odziva: SAM $\large{*}$
#
# ■ Merjenje potopitve: FSS $\large{*}$
#
# ■ Merjenje kratkoročne multimedijske izpostavljenosti oglasom: MMAES $\large{*}$
#
# ■ Uporabniška izkušnja: UEQ $\large{*}$
#
# ■ Merjenje obremenitve: NASA TLX, instrument $\large{*}$
#
# ■ Merjenje kvalitete dvogovora: SUISQ $\large{*}$
#
# ■ K uporabi instrumentov in konstruktov
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 3 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Uvod: Zakaj psihološki konstrukti v tehnologiji?
#
#
# Psihološki konstrukti so izjemnega pomena pri merjenju uporabnikov izven realnega časa, ki poteka na osnovi uporabnikovega samoporočanja v obliki odgovorov na vprašanja. Sestavljeni so iz instrumenta (seznama vprašanj, ki jih merjenec - uporabnik odgovori) in specifične strukture iz ene ali več dimenzij oz. vidikov, ki jih na podlagi teh odgovorv ocenimo v številski obliki. Npr. konstrukt uporabnosti ima eno dimenzijo "uporabnost", ki jo ocenimo na podlagi odgovorov na 10 skrbno izbranih vprašanj. Ta vprašanja so izbrana na podlagi tako imenovane operacionalizacije in enega ali več eksperimentov na realnih merjencih, ki jim sledi multivariantna statistična analiza. Namen slednje je ocena ali ta nabor vprašanj 1. meri tisto, za kar je namenjen (veljavnost) in 2. to meri stabilno in zanesljivo (zanesljivost).
#
# Zakaj uporabnika priprosto ne vprašamo "Ali se vam ta storitev zdi dobra?", ampak ga vprašamo večje število posrednih vprašanj? Enostavno zato, ker je človeški naravni jezik premalo natančen, da bi dobili stabilne in veljavne odgovore. Eksperimenti so pokazali, da uporabniki ob vprašanju "storitev je dobra" pomislijo na izjemno različne vidike, od oblike in strukture vmesnika do specifičnih lastnosti same storitve. Zato so odgovori zelo raztreseni in tako za usmerjanje konkretnega razvoja aplikacij in storitev neuporabni. Rešitev je v tem, da uporabnika vprašamo več bolje definiranih vprašanj in nato analiziramo odgovore. Ker so tako vprašanja kot odgovori med sabo povezani, jih z redukcijo dimenzije (multivariantna statistika) povzamemo v čimmanjšem številu dimenzij, ki nato sestavljajo konstrukt. Tem dimenzijam oziroma skalam dodamo operativni pomen in posledično postanejo berljive za človeka.
#
# Pomen psiholoških konstruktov v tehnologiji je izjemen. Izbran nabor uporabnikovih stanj in obnašanj konstukt 1. Definira in 2. Naredi ga merljivega. Tak konstrukt je npr. Uporabnost sistema. Kaj je uporabnost pred izdelavo instrumenta in konstrukta ni bilo znano oz. definirano na način, ki bi bil uporaben v razvoju storitev in aplikacij. Danes pa pod izrazom uporabnost razumemo tisto, kar ta konstrukt oceni! Realno izvedljivo merjenje (merljivost) pa je seveda potreben pogoj za kakršnokoli uporabnost v realnem tehnološkem razvoju.
#
# Glede na napisano je razumljivo, da je izdelava lastnega vprašalnika za praktično uporabo vedno napačna odločitev. Prava odločitev je izbor ustreznega obstoječega validiranega inatrumenta in konstrukta. Kot kažejo izkušnje gradnje novih instrumentov in konstruktov, ta zahteva obsežne eksperimente, večkrat v več zaporednih izvedbah in zahtevne analize na področju multivariantne statistike. Zako je izdealva lastnega vprašalnika obsojena na neuspeh v smislu veljavnosti (kaj meri) in zanesljivosti (daje stabilne rezultate).
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Kaj je instrument in kaj je konstrukt
#
#
# #### Konstrukt
#
# Konstrukt je teoretični okvir človeškega onbašanja, lastnosti ali mnentalnih procesov, Nas zanimajo obnašanja ali lastnosti, relevantna za uporabniško interakcijo s pametninimi sistemi. Konstrukti so navadno sestavljeni iz večih dimenzij, označujejo posamezne vidike lastnosti ali obnašanja in jih podajamo s posameznimi števili. Konstrukt označuje model, ki ima več neodvisnih dimenzij. Če je dimenzija ena sama, jo imenujemo skala.
#
# Bistvena lastnost konstruktov je njihova povezava z instrumenti, ki dan konstrukt naredijo merljiv.
#
# Npr. konstrukt osebnosti Velikih (glejte spodaj) opisuje osnovno značilnosti osebnosti uporabnika in je sestavljen iz petih dimezij. Vsaka pokriva svoj vidik in njegovo intenzivnost podamo s številom med 0 in 100 (ali med 0 in 1).
#
#
# ##### Def.: Psihološki konstrukt je orodje, ki se uporablja za lažje razumevanje človeškega vedenja. Identificira pomembne vidike izbranega obnašanja in nudi način merjenja teh vidikov.
#
#
# ##### Dimenzije:
# Pojem, ki ga psihološki konstrukt opisuje, lahko zajema več (vsaj delno) neodvisnih značilnosti. Imenujemo jih dimenzije. Psihološki konstrukt ima dimenzije
# $$ d_1, \ldots, d_N, $$
# ki so med sabo neodvisne in vsaka ima svojo interpretacijo.
#
# Npr. pri modelu osebnosti Velikih 5 je $N=5$ dimenzij, in te dimenzije so
#
# | Dimenzija | Opis |
# |-----------|------|
# | Sprejemljivost | ohranjanje pozitivnih odnosov z drugimi |
# | Ekstravertnost| zanimanje za družabne dogodke, aktivnost, energičnost  |
# | Vestnost | odgovornost, naklonjenost pravilom, vztrajnost, pozornost |
# | Odprtost | odprtost za nove izkušnje, kulturna sofisticiranost  |
# | Nevroticizem | obvladovanje čustev, anksioznost  |
#
#
#
# Dimenzije konstrukta navadno niso zares neodvisne.
#
#
#
# #### Instrument
#
# Instrument je seznam vprašanj ali nalog, ki jih uporabnik odgovori pred, med ali po seji interakcije s sistemom.
#
# Primer instrumenta in konstrukta je na sliki.
#
# <img style="float: center; width: 200px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-NasaTlx.png">
#
# Vprašanja so lahko podana v elektronski ali papirnati obliki. Naloge so podano grafično ali kako drugače.
#
# Primer instrumenta, ki ni v obliki vprašanj, je isntrument FeelTrace za zajem afektivnih in posledično emotivnih stanj.
#
# <img style="float: center; width: 250px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/FeelTraceInstr.png">
#
#
#
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 4 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Izbrani konstrukti v interakciji s (pametnimi) sistemi
#
#
# Psihološki konstrukti izbran okvir uporabnikovega stanja in obnašanja šele definirajo in ga naredijo merljivega.
#
# Pomembni konstrukti v interakciji uporabnika s (pametnimi) sistemi so:
# 1. **Uporabnost**: Kako enostavno je uporabljati sistem.
#
# 2. **Zadovoljstvo**: Kako se uporabnik čustveno odzove po uporabi sistema.
#
# 3. **Kognitivna obremenitev**: uporabnik se z uporabo izdelka ali storitve seznani in se z njo strinja: Kognitivni napor: miselni napor, ki je potreben med interakcijo.
#
# 4. **Afektivna in čustveno stanje**: Uporabnikov afektivni in čustveni odziv na sistem (pozitiven ali negativen).
#
# 5. **Angažiranost**: Uporabnikova vključenost in potopitev v interakcijo.
#
# 6. **Motivacija**: dejavniki, ki uporabnike spodbujajo k uporabi sistema.
#
# 7. **Specifilni konstrukti po področjih**:
# - kvaliteta govornega vmesnika
# - interakcija s pametnim domom
# - ...
#
# 8. **Dostopnost**: uporabnost za uporabnike s posebnimi potrebami.
#
# 9. **Zaznani nadzor**: Občutek nadzora nad sistemom.
#
# 10. **Frustracija**: Frustracija: Negativni čustveni odziv, ki ga povzročijo težave v sistemu.
#
# 11. **Zaupanje**: Zaupanje v funkcionalnost in varnost sistema.
#
# 12. **Estetika**: Vizualna privlačnost in lepota vmesnika.
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 5 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Uporabnost (Usability): sistemska uporabnost SUS
#
#
# #### Meri: sistemsko uporabnost storitve, naprave ali sistema. Služi za prvo oceno ali je neka storitev uporabna za dano skupino uporabnikov.
#
# #### Skala: realno število, ki podaja sistemsko uporabnost storitve
#
#
# #### Instrument
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-UsabilitySUS.png">
#
# #### Določanje točk
#
# Odgovori so na skali 1 - 5. Odgovor na $i$-to vprašanje označimo z $qa_i$.
# Enačba za določanje točk je
# $$ SUS = 2.5\left(20 + (qa_1 + qa_3 + qa_5 + qa_7 + qa_9) - (qa_2 + qa_4 + qa_6 + qa_8 + qa_{10})\right). $$
#
#
#
# <br>
# Vir: [Sistemska uporabnost](https://www.usability.gov/how-to-and-tools/methods/system-usability-scale.html)
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 5 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Uporabnost (Usability): Uporabnost interakcije UMUX
#
# #### Instrument
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-UMUX.png">
#
# https://www.usability.gov/how-to-and-tools/methods/system-usability-scale.html
#
#
# #### Določanje točk
#
# Odgovori so na skali 0 - 6 (to je koda odgovora - 1). Odgovor na $i$-to vprašanje označimo z $qa_i$.
# Enačba za določanje točk je
# $$ UMUX = \frac{100}{24}\left((qa_1 + qa_3) - (qa_2 + qa_4)\right). $$
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 7 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje osebnosti: velikih 5 (Big5)
#
# #### Meri: osebnost. Neposrednih navodil za uporabnost v prilagajanju uporabnikom ni. Osebnost uporabimo pri izdelavi profilov uporabnikov.
#
# #### Konstrukt: model osebnosti s petimi dimenzijami
#
# |Dimenzija |Opis  |
# |:--- |:--- |
# |**Sprejemljivost**|Sprejemljivost se nanaša na sposobnost razumevanja z drugimi osebami in nam pomaga, da premagamo frustracije, ki so povezane z življenjem v skupini. |
# |**Ekstravertnost**|Ekstravertne osebe se v veliki meri zanimajo za družabne dogodke, so zelo aktivne in energične. |
# |**Vestnost**|Vestnost zajema lastnosti kot so odgovornost, naklonjenost pravilom, vztrajnost, pozornost |
# |**Odprtost**|Osredotoča pa se predvsem na posameznikovo kulturno sofisticiranost in posameznikovo odprtost za nove izkušnje. |
# |**Nevroticizem**|Posamezniki, ki imajo visoko izražen nevroticizem so v manjši meri sposobni obvladovati čustva, so bolj anksiozni. |
#
#
#
# #### Instrument: 44 vprašanj (angl. Big Five inventory, BFI)
#
# Instrument sestavlja 44 vprašanj z različnih podpodročij.
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-BFI_44.png">
#
#
# Ta instrument (44 vprašanj) je najbolj primeren za določanje osebnosti v okviru prilagajanja storitev. Obstajata še več drugih instrumentov (npr. NEO-PI-R z 240 vprašanji in TIPI z 10 vprašanji), ki so manj primerni ali neprimerni za uporabo v našem okviru.
#
#
# #### Določanje točk
#
# Odgovori so kodirani 1 - 5. Odgovori na "negativna" vprašanja je potrebno obrniti, to je 5->1, 4->2, 3->3, 2->4, 1->5. Nato za vsako dimenzijo seštejemo število točk pripadajočih vprašanj kot kaže spodnjda tabela.
#
# |Dimenzija |Vprašanja  pozitivna| Vprašanja negativna |
# |:--- |:--- |:--- |
# |**Sprejemljivost**| 7, 17, 22, 32, 42 | 2, 12, 27, 37 |
# |**Ekstravertnost**| 1, 11, 16, 26, 36 | 6, 21, 31 |
# |**Vestnost**| 3, 13, 28, 33, 38 | 8, 18, 23, 43 |
# |**Odprtost**| 5, 10, 15, 20, 25, 30, 40, 44 | 35, 41 |
# |**Nevroticizem**| 4, 14, 19, 29, 39 | 9, 24, 34 |
#
# Opomba: nekateri sistemi namesto vsote podajajo povprečje točk.
#
# <br><br>
# Vir: [Center za psihodiagnostična sredstva](https://www.center-pds.si/)
#
#
# #### Uporaba
# Na odločanje uporabnikov šibko vplivajo dimenzije Sprejemljivost in Odprtost.
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 8 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
## Zajem osebnosti Velikih 5
import ipywidgets as widgets
import numpy as np


# Definicija vprašalnika

m = 50
tab_contents = ["Q" + str(i) for i in range(1,m+1)]

# Vprašanja
list_of_questions = ["Am the life of the party", "Feel little concern for others.", "Am always prepared.", "Get stressed out easily.",
             "Have a rich vocabulary.", "Don't talk a lot.", "Am interested in people.", "Leave my belongings around.",
             "Am relaxed most of the time.", "Have difficulty understanding abstract ideas.", "Feel comfortable around people.",
             "Insult people.", "Pay attention to details.", "Worry about things.", "Have a vivid imagination.",
             "Keep in the background.", "Sympathize with others' feelings.", "Make a mess of things.", "Seldom feel blue.",
             "Am not interested in abstract ideas.", "Start conversations.", "Am not interested in other people's problems.",
             "Get chores done right away.", "Am easily disturbed.", "Have excellent ideas.", "Have little to say.",
             "Have a soft heart.", "Often forget to put things back in their proper place.", "Get upset easily.",
             "Do not have a good imagination.", "Talk to a lot of different people at parties.",
             "Am not really interested in others.", "Like order.", "Change my mood a lot.", "Am quick to understand things.",
             "Don't like to draw attention to myself.", "Take time out for others.", "Shirk my duties.", "Have frequent mood swings.",
             "Use difficult words.", "Don't mind being the center of attention.", "Feel others' emotions.", "Follow a schedule.",
             "Get irritated easily.", "Spend time reflecting on things.", "Am quiet around strangers.", "Make people feel at ease.",
             "Am exacting in my work.", "Often feel blue.", "Am full of ideas."]

# Možni odgovori
options = ["Very Inaccurate", "Moderately Innacurate", "Neither Accurate nor Innacurate", "Moderately Accurate", "Very Accurate"]
list_of_options = [options] * m

 

# "radio" gumbi
children = [widgets.RadioButtons(options=opt) for opt in list_of_options]


# Implementacija vprašalnika - uporaba widgeta
# sestava: labela(vprašanje, widget (radio gumbi))
questions = [widgets.HBox([widgets.Label(name), child])
            for name, child in zip(list_of_questions, children)]


# Poimenuj vprašanja za lažjo orientacijo
tab = widgets.Tab()

tab.children = questions
for i in range(len(questions)):
    tab.set_title(i, tab_contents[i])

# %%
## Izvedba merjenja
tab

# %%
## Definicija modela osebnosti - določitev uteži za posamezne lastnosti

# Pretvorba opisnih odgovorov v številske
map_dict = {k:v for k, v in zip(options, [0, 1, 2, 3, 4])}
aQ = [map_dict[x.value] for x in children]


# Definicija uteži - to je modela
Sprejemljivost_d1 = (100 / 40) * (aQ[0] + 4 - aQ[5] + aQ[10] + 4 - aQ[15] + aQ[20] + 4 - aQ[25] + aQ[30] + 4 - aQ[35] + aQ[40] + 4 - aQ[45])
Ekstravertnost_d2 = (100 / 40) * (aQ[6] + 4 - aQ[1] + aQ[16] + 4 - aQ[11] + aQ[26] + 4 - aQ[21] + aQ[36] + 4 - aQ[31] + aQ[46] + 4 - aQ[41])
Odprtost_d3 = (100 / 40) * (aQ[2] + 4 - aQ[7] + aQ[12] + 4 - aQ[17] + aQ[22] + 4 - aQ[27] + aQ[32] + 4 - aQ[37] + aQ[42] + 4 - aQ[47])
Vestnost_d4 = (100 / 40) * (aQ[8] + 4 - aQ[3] + aQ[18] + 4 - aQ[13] + aQ[28] + 4 - aQ[23] + aQ[38] + 4 - aQ[33] + aQ[48] + 4 - aQ[43])
Nevroticizem_d5 = (100 / 40) * (aQ[4] + 4 - aQ[9] + aQ[14] + 4 - aQ[19] + aQ[24] + 4 - aQ[29] + aQ[34] + 4 - aQ[39] + aQ[44] + 4 - aQ[49])

# %%
## Izpis
print ("Izmerjene dimenzije Velikih 5 (lastnosti) so:")
print ("Sprejemljivost:", Sprejemljivost_d1) 
print ("Ekstravertnost:", Ekstravertnost_d2)
print ("Odprtost:", Odprtost_d3)
print ("Vestnost:", Vestnost_d4)
print ("Nevroticizem:", Nevroticizem_d5)

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje razpoloženja: Lestvica pozitivnega in negativnega afekta (PANAS)
#
# #### Meri: pozitiven in negativen afekt.
#
# #### Uporabnost:
# - oceni s strani uporabnika ocenjen afekt po eksperimentu.
# - predznak afekta vpliva na občutenje težavnosti posamezne naloge ter na uspešnost reševanja nalog interakcije
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |**Pozitiven afekt (PA)**|Meri stopnjo občutkov entuziastičnosti, aktivnosti in budnosti |
# |**Negativen afekt (NA)**|Meri negativna čustvena stanja kot so zaničevanje, gnus, strah itd. |
#
#
#
# #### Instrument
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-PANAS.png">
#
#
#
# #### Določanje točk
#
# Odgovori so točkovani 1 - 5. Označimo jih z $qa_1, \ldots, qa_{20}$. Točke določimo
# $$ \text{PA} = \sum_{i=1}^{10} qa_i, \qquad \text{NA} = \sum_{i=11}^{20} qa_i. $$
#
#
#
# <br><br>
# Vir: [Center za psihodiagnostična sredstva](https://www.center-pds.si/)
# Vir: [What is the Positive and Negative Affect Schedule? (PANAS)](https://positivepsychology.com/positive-and-negative-affect-schedule-panas/)
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje angažiranosti: UES
#
# #### Meri: uporabnikov angažiranost pri uporabi sistena
#
# #### Uporabnost:
# - Ocena angažiranosti uporabnikov obstoječih rešitev
# - načrtovanje izboljšav rešitev
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |** Focused attention (FA)**| Feeling absorbed in the interaction and losing track of time |
# |** Perceived usability (PU)**| Negative affect experienced as a result of the interaction and the degree of control and effort expended |
# |** Aesthetic appeal (AE)**| Attractiveness and visual appeal of the interface |
# |** Reward (RW)**| Positive feelings and satisfaction users get from interacting with the system  |
#
#
#
#
# #### Instrumenta in določanje točk
#
# Vprašanja pri obeh instrumentih so kodirana na Likertovi lestvici "Strongly disagree, Disagree, Neither agree nor disagree, Agree, Strongly agree" s kodami 1 2 3 4 5.
#
#
# ##### Instrument UES-LF
#
# Daljša oblika instrumenta s 30 vprašanji.
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-UES-LF.png">
#
# Točke posameznih dimenzij določimo tako, da:
# 1. Obrnemo odgovore na vprašanja (1->5, ..., 5->1) na vprašanja PU-1, ..., PU-6, PU-8, in RW-3;
# 2. Povprečimo vrednosti pripadajočih odgovorov:
#     - FA: povprečje FA.1 - FA.7
#     - PU: povprečje PU.1 - PU.8
#     - AE: povprečje AE.1 - AE.5
#     - RW: povprečje RW.1 - RW.10
#
#
#
# ##### Insturment UES-SF
# Krajša oblika instrumenta z 12 vprašanji.
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-UES-SF.png">
#
#
#
# Točke posameznih dimenzij določimo tako, da:
# 1. Obrnemo odgovore na vprašanja (1->5, ..., 5->1) na vprašanja PU-S1, PU-S2 in PU-S3;
# 2. Povprečimo vrednosti pripadajočih odgovorov:
#     - FA: povprečje FA.S1 - FA.S3
#     - PU: povprečje PU.S1 - PU.S3
#     - AE: povprečje AE.S1 - AE.S3
#     - RW: povprečje RW.S1 - RW.S3
#
#
# <br><br>
# Vir: O'Brien et. al. A practical approach to measuring user engagement with the refined user engagement scale (UES) and new UES short form, International Journal of Human-Computer Studies, 2018.
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje čustvenega odziva: SAM
#
# #### Meri: afektivno stanje uporabnika v prostoru VAD
#
# #### Uporabnost:
# - merjenje uporabnikovega afektivnega in čustvenega stanja
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |**Valence**| Pleasantness or unpleasantness a person feels in response to a stimulus. It reflects how positive or negative the emotion is. |
# |**Arousal**| Intensity of the emotional response, specifically whether the person feels activated or calm. |
# |**Dominance**| The level of control or power the person feels in the situation. |
#
#
#
# #### Instrument
#
# Instrument je grafičen, tu je prikazana originalna oblika (Valence je poimenovan kot Peasure)
#
# <img style="float: center; width: 550px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-ManikinSAM.jpg">
#
#
#
# #### Določanje točk
#
# Točke določamo neposredno iz uporabnikove izbire na instrumentu in je odvisno od same dimenzije.
#
# ##### 1. Valence:
# 1 = Very unhappy or unpleasant (extremely negative emotion), ..., 5 = Neutral, ..., 9 = Very happy or pleasant (extremely positive emotion)
#
#
# ##### 2. Arousal
# 1 = Extremely calm or relaxed, ..., 5 = Neutral arousal, ..., 9 = Extremely excited or aroused
#
# ##### 3. Dominance
# 1 = Feeling highly submissive or powerless, ..., 5 = Neutral dominance, ..., 9 = Feeling highly dominant or in control
#
#
# <br><br>
# Vir: Bradley et. al. Measuring emotion: The self-assessment manikin and the semantic differential, Journal of Behavior Therapy and Experimental Psychiatry, 1994.
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje potopitve (angl. Flow State Scale FSS)
#
# #### Meri: Potopitev v vuporabo apliakcije
#
# #### Uporabnost: merjenje aplikacije s specifično uporabo kot so podporne aplikacije za učenje.
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |**Challenge-Skill Balance**|Balance between task difficulty and individual skill level.|
# |**Clear Goals**|Presence of clearly defined and attainable goals.|
# |**Unambiguous Feedback**|Immediate, clear feedback on performance.|
# |**Concentration on the Task at Hand**|Intense focus and exclusion of distractions.|
# |**Sense of Control**|Strong feeling of control over actions and the task.|
# |**Loss of Self-Consciousness**|Reduced self-awareness, focusing entirely on the task.|
# |**Transformation of Time**|Altered perception of time (slowing down or speeding up).|
# |**Autotelic Experience**|Intrinsic enjoyment and fulfillment from the activity itself.|
#
#
#
# #### Instrument
#
# <!-- <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-PANAS.png"> -->
#
# |Dimenzija|Vprašanje|
# |:--- |:--- |
# |**Challenge-Skill Balance**| Do you feel that the task challenges your abilities in a way that matches your skills? |
# |**Clear Goals**| Do you clearly understand what you are supposed to achieve during the task? |
# |**Unambiguous Feedback**| Are you able to receive feedback about your performance as you proceed? |
# |**Concentration on the Task at Hand**| Do you find it easy to concentrate on the task without being distracted? |
# |**Sense of Control**| Do you feel in control of what you are doing? |
# |**Transformation of Time**| Do you lose track of time while engaged with the task? |
# |**Autotelic Experience**| Do you find the task enjoyable regardless of the outcome? |
#
# #### Določanje točk
#
# Neposreden odčitavanje odgovorov.
#
#
# <br><br>
# <!--Vir: [Center za psihodiagnostična sredstva](https://www.center-pds.si/) -->
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje kratkoročne multimedijske izpostavljenosti oglasom MMAES
#
# #### Meri: kratkoročna izpostavljenost multimedijskim oglasom
#
# #### Uporabnost:
#
# - merjenje učinkov vidoe oglasov
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |**Ad Engagement (AE)**| Measures engagement in the advertisement in terms of viewer’s attention and emotional experience (amusement, excitement, contentment, interest, esthetic appeal, surprise). |
# |**Reactance (RE)**| Measures viewer’s subjective disturbance in terms of negative emotional experience (reactance) towards the advertisement, product, or brand. |
# |**Awareness and Attitude (AA)**|  Measures the likability and/or desirability of the advertised brand/product. |
# |**Purchase Intention (PI)**| Measures willingness to buy the product. |
#
#
# #### Instrument
#
# <img style="float: center; width: 450px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-MMAES.png">
#
#
#
# #### Določanje točk
#
# Točke izračunamo kot povprečje točk pripadajočih vprašanj.
#
#
# <br><br>
# Vir: Oguz, Košir: Multimedia ad exposure scale: measuring short-term
# impact of online ad exposure, Multimedia tools and applications, 2023.
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Uporabniška izkušnja: UEQ
#
# #### Meri: Uporabniško izkušnjo z interaktivnimi sistemi
#
# #### Uporabnost:
# - uporabniška izkušnja z interaktivnimi sistemi
# - uporabno tako za produkte kot storitve
#
#
# #### Konstrukt
#
# |Dimenzija|Opis|
# |:--- |:--- |
# | Attractiveness | Overall impression of the product. Do users like or dislike the product? |
# | Perspicuity | Is it easy to get familiar with the product? Is it easy to learn how to use the product? |
# | Efficiency | Can users solve their tasks without unnecessary effort? |
# | Dependability | Does the user feel in control of the interaction? |
# | Stimulation | Is it exciting and motivating to use the product? |
# | Novelty | Is the product innovative and creative? Does the product catch the interest of users? |
#
#
# #### Instrument
#
# <img style="float: center; width: 450px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-UEQ_slo.png">
#
# Odgovori so kodirani na 7 stopenjski lstvici -3, -2, ..., 2 - 3, kjer je
# | Koda | Opis |
# |:--- |:--- |
# |-3 | Strong preference for the negative adjective (e.g., "complicated") |
# |-2 | Moderate preference for the negative adjective |
# |-1 | Slight preference for the negative adjective |
# |0  | Neutral |
# |+1 | Slight preference for the positive adjective (e.g., "easy") |
# |+2 | Moderate preference for the positive adjective |
# |+3 | Strong preference for the positive adjective |
#
#
# #### Določanje točk
#
# Odgovori so točkovani na 7 stopenjski lstvici -3, -2, ..., 2 - 3.
#
#
# |Dimenzija |Vprašanja  pozitivna| Vprašanja negativna |
# |:--- |:--- |:--- |
# |**Attractiveness**| 1, 2 | 3, 4, 5, 6 |
# |**Perspicuity**| 7, 8 | 9, 10 |
# |**Efficiency**| 11, 13, 14 | 12 |
# |**Dependability**| 15, 16, 18 | 17 |
# |**Stimulation**| 20, 22 | 19, 21 |
# |**Novelty**| 26 | 23, 24, 25 |
#
# Glede na zgornjo tabela odgovore na negativna vprašanja obrnemo (-3 -> 3, -2 -> 2, -1 -> 1, 0 -> 0, ..., 3 -> -3) in povprečimo točke vseh odgovorov, ki pripadajo pozamezni dimenziji.
# Npr. za Attractiveness obrnemo točke za vprašanja 3, 4, 5, 6, seštejemo točke vprašanj 1 - 6 in dobljeno vsoto delimo s 6.
#
#
# <br><br>
#
# https://www.ueq-online.org/
#
#
# Martin Schrepp User Experience Questionnaire Handbook - All you need to know to apply the UEQ successfully in your project, 2023, dostopno https://www.ueq-online.org/Material/Handbook.pdf.
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 11 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje obremenitve: NASA TLX
#
# #### Meri: obremenitev med aktivnostjo (med uporabniškim eksprerimentom). Za prilagajanje uporabnikom je zanimivih več dimenzij, predvsem "mental demand", "effort" in "frustration level".
#
#
# #### Konstrukt: model obremenitve s šestimi dimenzijami
#
# Dimenzije in opis navajamo v originalni izvedbi, to je v angleškem jeziku.
#
# |Dimenzija|opis|
# |:--- |:--- |
# |**Mental Demand**|How much mental and perceptual activity was required? Was the task easy or demanding, simple or complex?|
# |**Physical Demand**|How much physical activity was required? Was the task easy or demanding, slack or strenuous?|
# |**Temporal Demand**|How much time pressure did you feel due to the pace at which the tasks or task elements occurred? Was the pace slow or rapid?|
# |**Overall Performance**|How successful were you in performing the task? How satisfied were you with your performance?|
# |**Effort**|How hard did you have to work (mentally and physically) to accomplish your level of performance?|
# |**Frustration Level**|How irritated, stressed, and annoyed versus content, relaxed, and complacent did you feel during the task?|
#
#
# #### Instrument
#
# Instrument sestavlja šest ocen, za vsako dimenzijo po eno oceno.
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-NasaTlx.png">
#
#
# ##### Določanje točk
#
# Za vsako dimenzijo točke določimo neposredno z odčitkom uporabnikovega vnosa.
#
#
#
# <br><br>
# Vir [NASA-TLX](https://en.wikipedia.org/wiki/NASA-TLX)
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 13 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ Merjenje kvalitete pogovora: SUISQ
#
#
# #### Meri: lastnosti govornega vmesnika (npr. Google asistant ali Amazon Alexa)
#
# #### Konstrukt: model osebnosti s petimi dimenzijami
#
# |Dimenzija|Opis|
# |:--- |:--- |
# |**User goal orientation**|Ciljna usmerjenost uporabnika: kako dobro sistem podpira konkretne uporbnikov cilj pri pogovoru.|
# |**Customer service behavior**|Obnašanje storitev za stranke: funkcioniranje storitve s stališča pričakovanih učinkov.|
# |**Speech characteristics**|Značilnosti govora: kvaliteta govora v smislu zakasnitev, tekočnosti ipd. |
# |**Verbosity**|Podrobnosti, ki so na voljo: specifične informacije za glede same teme pogovra v smislu detaljnih informacij ipd.|
#
#
# #### Instrumenti in določanje točk
#
# Instrument SUSIQ sestavlja 25 vprašanj, validiran slovenski prevod ne obstaja. Odgovori so na 5 stopenjski Likertovi lestvici "Extremely Dissatisfied, Dissatisfied,
# Neither Satisfied nor Dissatisfied, Satisfied, and Extremely Satisfied", ki jim dodelimo točke 1 - 5.
#
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-SUISQ.png">
#
# Točke določimo kot povprečja točk odgovorov v tabeli navedenih inddeksov vprašanj, kodiranih z 1 - 5. Pri dimenziji V je potrebno kode odgovorov obrniti po enačbi 8 - V.
#
# | Dimenzija | Vprašanja |
# |:-----|:------|
# | User goal orientation (UGO) | 1, 3, 5, 10, 12, 13, 17, 19|
# | Customer service behaviour (CSB) | 4, 6, 7, 9, 11, 21, 23, 25 |
# | Speech characteristics (SC) | 14, 16, 18, 20, 24 |
# | Verbosity (V) | 2, 8, 15, 22 |
#
#
#
#
#
# Obstajata dve krajši verziji instrumetov in sicer:
#
# ##### SUISQ-R (reduced): 14 vprašanj
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-SUISQ-R.png">
#
# Pri dimenziji V je potrebno kode odgovorov obrniti po enačbi 8 - V.
#
# | Dimenzija | Vprašanja |
# |:-----|:------|
# | User goal orientation (UGO) | 1, 2, 3, 4|
# | Customer service behaviour (CSB) | 5, 6, 7, 8 |
# | Speech characteristics (SC) | 9, 10, 11  |
# | Verbosity (V) | 12, 13, 14 |
#
#
#
# ##### SUISQ-MR: 8 vprašanj
# <img style="float: center; width: 350px; margin: 20px 20px 50px 0;" src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/Instrument-SUISQ-MR.png">
#
# Pri dimenziji V je potrebno kode odgovorov obrniti po enačbi 8 - V.
#
# | Dimenzija | Vprašanja |
# |:-----|:------|
# | User goal orientation (UGO) | 1, 2|
# | Customer service behaviour (CSB) | 3, 4|
# | Speech characteristics (SC) | 5, 6 |
# | Verbosity (V) | 7, 8, 9|
#
# Pričakovano so merske karakteristike krajših verzij slabše od osnovne variante instrumenta s 25 vprašanji.
#
#
# <br><br>
# Vir [Investigating the psychometric properties of the Speech User
# Interface Service Quality questionnaire](https://dl.acm.org/doi/abs/1.1007/s10772-015-9289-1)
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 15 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.1.Izbrani instrumenti - vprašalniki in konstrukti </div>
# </div>
#
#
# # ■ K uporabi instrumentov in konstruktov
#
# 1. Za nekatere instrumente potrebujemo izvajalce z licenco
#
#
# 2. Vsaka sprememba instrumenta razveljavi merske karakteristike instrumenta in konstrukt. Take spremembe so:
#     - prevajanje v drug jezik
#     - prenos v drugo "kulturo"
#     - sprememba postopka
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 17 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.2. Ocena dimenzij konstrukta </div>
# </div>
#
#
# # 1.2. Izračun metrike uspešnosti - ocena dimenzij konstrukta, instrument
#
# ■ Uvod in primer SUISQ
#
# ■ Uteži faktorske matrike definirajo konstrukt
#
# ■ Izračun točk konstrukta ali skale
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 18 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.2. Izračun metrike uspešnosti - ocena dimenzij konstrukta </div>
# </div>
#
#
# # ■ Uvod in primer SUISQ
#
# Primer SUISQ: glejte prejšnje poglavje in članek
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 19 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.2. Izračun metrike uspešnosti - ocena dimenzij konstrukta </div>
# </div>
#
#
# # ■ Uteži faktorske matrike definirajo konstrukt
#
# #### Izračun metrike uspešnosti
#
# Faktorska matrika da **uteži**, s katerimi množimo številske vrednosti odgovorov in s tem ocenimo posamezne latentne spremenljivke - dimenzije. S tem je definiran sam konstrukt.
#
# Dobljene uteži so navedene spodaj. To so uteži, s pomočjo katerih iz odgovorov pridobimo ocene dimenzij (latentnih faktorjev) UGO, CSB, SC in V za posamezne respondente.
#
#
# |Vprašanje|UGO | CSB | SC | V |
# |:-|:-:|:-:|:-:|:-:|
# | 1.The system made me feel like I was in control. | 0.799 | 0 | 0 | 0 |
# | 2. The messages were repetitive. | 0 | 0 | 0 | 0.706 |
# | 3. The system gave me a good feeling about being a customer of this business. | 0.8 | 0 | 0 | 0 |
# | 4. The system used terms I am familiar with. | 0 | 0.711 | 0 | 0 |
# | 5. I could find what I needed without any difficulty. | 0.805 | 0 | 0 | 0 |
# | 6. The system used everyday words. | 0 | 0.758 | 0 | 0 |
# | 7. The system was organized and logical. | 0.628 | 0 | 0 | 0 |
# | 8. The system gave me more details than I needed. | 0 | 0 | 0 | 0.701 |
# | 9. The system spoke at a pace that was easy to follow. | 0 | 0.736 | 0 | 0 |
# | 1.The system would help me be productive. | 0.831 | 0 | 0 | 0 |
# | 11.The system seemed polite. | 0 | 0.739 | 0 | 0 |
# | 12. I could trust this system to work correctly. | 0.834 | 0 | 0 | 0 |
# | 13. I would be likely to use this system again. | 0.858 | 0 | 0 | 0 |
# | 14. The system’s voice was pleasant. | 0 | 0.726 | 0 | 0  |
# | 15. The system was too talkative. | 0 | 0 | 0 | 0.655 |
# | 16. The system’s voice sounded like people I hear on the radio or television. | 0 | 0 | 0.585 | 0 |
# | 17. I felt confident using this system. | 0.834 | 0 | 0 | 0 |
# | 18. The system’s voice sounded like a regular person. | 0 | 0 | 0.808 | 0 |
# | 19. The quality of this system made me want to remain a customer of this business. | 0.794 | 0 | 0 | 0 |
# | 20. The system’s voice sounded natural. | 0 | 0 | 0.797 | 0 |
# | 21.The system seemed courteous. | 0 | 0.599 | 0 | 0 |
# | 22. I felt like I had to wait too long for the system to stop talking so I could respond. | 0 | 0 | 0 | 0.73 |
# | 23. The system seemed friendly. | 0 | 0.648 | 0 | 0 |
# | 24. The system’s voice sounded enthusiastic or full of energy. | 0 | 0 | 0.658 | 0 |
# | 25. The system seemed professional in its speaking style. | 0 | 0.668 | 0 | 0 |
#
#
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 20 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.2. Izračun metrike uspešnosti - ocena dimenzij konstrukta </div>
# </div>
#
#
# # ■ Izračun točk konstrukta ali skale
#
# Rezultat merjenja s psihološkim instrumentom določimo z izračunom točk skale oz. točl za posamezno dimenzijo večdimenzinalnega konstrukta. Te izračunamo neposredo iz odgovorov respondentov, ki so predstavljeni z numeričnimi vrednostmi Likertove lestvice. Npr. od "nerazumljiv" = 1 do "razumljiv" = 7.
#
# Navodilo za določanje točk je del samega instrumenta. Navadno je to preprosto povprečenje dogovorov, lahko pa zahteva tudi matrični račun ali celo optimizacijski postopek.
#
#
# ### Model konstrukta
#
# Model konstrukta dobimo neposredno iz rezultatov analize eksperimenta, s katerim je podan sam konstrukt. njegov bistven del je matrika uteži (angl. loading matrix).
#
#
# ##### Odgovori uporabnikov
#
# Matrika odgovorov uporabnikov $U$ na vprašanja $Q$,
# $$ X = [a_{uq}], \qquad u\in U, q\in Q, $$
# kjer je $U$ množica testnih uporabnikov in Q množica njihovih odgovorov na vprašanja.
#
# ##### Model je podan z matriko uteži
#
# Matrika uteži
# $$ L = [\lambda_{qi}], \qquad q\in Q, i\in F, $$
# kjer je Q množica njihovih odgovorov na vprašanja in $F$ množica faktorjev.
#
#
# #### Izračun točk (angl. sores)
#
# ##### 1. Povrečenje odgovorov
#
# Povprečenje izbranih odgovorov za izbrano deimenzijo oz. skalo, pri čemer so nekater odgovori obrnjeni (npr. 5 ->1, 4->2, ... 1 ->5).
#
# ##### 2. Matrični račun
#
# Matrika točk $S=[s_{ui}], u\in U, i\in F$, dana z
# $$ S = X.C^{\top}.L, $$
# kjer je $C$ kovariančna matrika odgovorov $X$.
#
# Mogoče je pokazati, da poenostavitev te formule vodi do povprečenja odgovorov in da povprečenje odgovorov da manj natačne točke kot ta formula.
#
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 21 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
## Estimate quality of speech interface 
# User Goal Orientation = UGO: 8 items, a = .92
# Customer Service Behaviors = CSB: 8 items, a = .89
# Speech Characteristics = SC: 5 items
# Verbosity = V: 4 items, a = .69


import numpy as np
import pandas as pd 
from scipy.optimize import minimize


# @brief reshape ND array to 1D as required by binary FA
# @arg nS number of samples
# @arg nQ number of questions
def reshape_NDto1D(a_nparr, nS, nQ):
    return a_nparr.T.reshape(nS*nQ)


# @brief reshape 1D array back to ND as required by binary FA
# @arg nS number of samples
# @arg nQ number of questions
def reshape_1DtoND(a_nparr, nS, nQ):    
    return a_nparr.reshape(nQ, nS).T


# @brief Get linear scores using direct optimisation. 
# @arg qa_mat anwsers matrix, users raws, questions columns
# @arg la_mat loadings  
# @arg cls0_trsh=0.5 ignored
# @ret S_star resulting scores
def get_linear_scores_D(qa_mat, la_mat, cls0_trsh=0.5):
    
    nS, nQ = qa_mat.shape # Number of samples and number of questions
    _, nF = la_mat.shape # Number of factors


    reg_la = 1.0 # Regularisation constant

    # Cost function    
    def cost_f(Sc_1D):
        Sc = reshape_1DtoND(Sc_1D, nS, nF)
        err_mat = qa_mat - Sc @ la_mat.T
        cost_err = np.linalg.norm(err_mat) + reg_la*np.abs(1 - np.linalg.norm(Sc))
        return cost_err


    # Minimsation
    S0 = np.ones((nS, nF)) / (1.0*np.sqrt(nS)) # To start with |S0|_2 = 1
    S0_1D = reshape_NDto1D(S0, nS, nF)
    
    
    res = minimize(cost_f, S0_1D) #, method='nelder-mead',
               #options={'xatol': 1e-8, 'disp': True})
    
    S_star = reshape_1DtoND(res.x, nS, nF) # This are scores    
    
    return S_star


# ---------------------------------------------------------------------------
# Load data 
post_fn = 'https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/2020-2021_PredPost-vprasalnik(dvogovor)(Responses).csv'
data_df = pd.read_csv(post_fn, header=0, sep=';', encoding='utf8')

#qs_weights_fn = 'https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/QualityOfConvSys_Weights.cvs'
#qs_weights_df = pd.read_csv(qs_weights_fn, header=0, sep=';', encoding='utf8')

qs_weights_df = pd.DataFrame(
[[0.799, 0, 0, 0],
[0, 0, 0, 0.706],
[0.8, 0, 0, 0],
[0, 0.711, 0, 0],
[0.805, 0, 0, 0],
[0, 0.758, 0, 0],
[0.628, 0, 0, 0],
[0, 0, 0, 0.701],
[0, 0.736, 0, 0],
[0.831, 0, 0, 0],
[0, 0.739, 0, 0],
[0.834, 0, 0, 0],
[0.858, 0, 0, 0],
[0, 0.726, 0, 0],
[0, 0, 0, 0.655],
[0, 0, 0.585, 0],
[0.834, 0, 0, 0],
[0, 0, 0.808, 0],
[0.794, 0, 0, 0],
[0, 0, 0.797, 0],
[0, 0.599, 0, 0],
[0, 0, 0, 0.73],
[0, 0.648, 0, 0],
[0, 0, 0.658, 0],
[0, 0.668, 0, 0]])




# Selectors 
post_qs_inds = list(range(11,36))
data_qs_df = data_df.iloc[:, post_qs_inds].drop([13])


# Estimate latent variables
qa_mat = data_qs_df.to_numpy()
la_mat = qs_weights_df.to_numpy()
speech_quality_est_np = get_linear_scores_D(qa_mat, la_mat) # was data_qs_df.dot(qs_weights_df.to_numpy())

speech_quality_est_df = pd.DataFrame(speech_quality_est_np)
speech_quality_est_df.columns = ['UGO', 'CSB', 'SC', 'V']

# %%
print ("Answers to the instrument questions:")
data_qs_df

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.2. Izračun metrike uspešnosti - ocena dimenzij konstrukta </div>
# </div>
#
#
# # ■ Izračun točk konstrukta ali skale
#
#
#
#
# ### Statistična ocena konstrukta ali skale
#
#
# ##### Odgovori uporabnikov
#
# Matrika odgovorov uporabnikov $U$ na vprašanja $Q$,
# $$ X = [a_{uq}], \qquad u\in U, q\in Q, $$
# kjer je $U$ množica testnih uporabnikov in Q množica njihovih odgovorov na vprašanja.
#
# ##### Model je podan z matriko uteži
#
# Matrika uteži
# $$ L = [\lambda_{qi}], \qquad q\in Q, i\in F, $$
# kjer je Q množica njihovih odgovorov na vprašanja in $F$ množica faktorjev.
#
#
# ##### Izračun točk (angl. sores)
#
# Matrika točk $S=[s_{ui}], u\in U, i\in F$, dana z
# $$ S = X.C^{\top}.L, $$
# kjer je $C$ kovariančna matrika odgovorov $X$.
#
#
#
#
# ### Poenostavitve: povprečje odgovorov
#
# Vrdnosti dimenzij so povprečja odgovorov. To je poenostavitev zgodnje formule, kjer predpostavimo, da so vse kovariance enake in vse faktorske uteži enake.
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 21 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
print ("Estimated scores of the construct:")
speech_quality_est_df

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.3. Merske karakteristike </div>
# </div>
#
#
# # 1.3. Merske karakteristike
#
# ■ Problem vprašalnikov in merske karakteristike
#
# ■ Veljavnost
#
# ■ Zanesljivost
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 21 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.3. Merske karakteristike </div>
# </div>
#
#
# # ■ Problem vprašalnikov in merske karakteristike
#
#
# #### Problem
#
# Vprašalniki lahko dajejo **neuporabne rezultate** ker odgoovri na vprašanja niso povezani z realnim stanjem. Razlogov za to je več:
# 1. Pojmi v vprašanjih ali vprašanja sama **niso dobro definirani**: izrazi v človeškem jeziku lahko hkrati nosijo več pomenov in če ti niso specificirani, se odgovori nanašajo na različne pojme, objekte itd
# 2. V vprašanju ni jasno, na kaj se nanaša - referenca ni podana: vprašnje se lahko nanaša na kvaliteto storitve, vmesnika, vsebine itd;
# 3. Vprašanja so lahko za testno osebo žaljiva ali moteča
# Posledično je nujno, da smo pri uporanbosti posameznih vprašanj skeptični.
#
# #### Rešitev
#
# Merske karakteristike zaznajo vprašanja, ki **ne delujejo**, to je ne dajejo smiselnih odgovorov. Gre za to, da merske karakteristike zaznavajo lastnosti odgovorov, ki vedno morajo veljati (npr. stabilnost ob večkratnih vprašanjih ipd) in s tem so dobre merske karkateristike **potreben pogoj za uporabnost odgovorov**, ne pa tudi zadosten pogoj.
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 22 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.3. Merske karakteristike </div>
# </div>
#
#
# # ■ Veljavnost
#
# #### Def.: merski instrument je veljaven, če res meri spremenljivko (pojem/pojav), za katerega je namenjen
#
# Veljavnost se torej dotika
#
# #### Preverjanje veljavnosti
#
# Veljavnosti ne moremo preveriti enostavno s statističnimi formulami. V rabi je predvsem:
# 1. Ocena človeških strokovnjakov na področju
# 2. Dovolj visoka korelacija (npr. $0.3$) s spremenljivkami, za katere pričakujemo, da je spremenljivka povezana;
#
#
# Pri človeški oceni primerjamo:
# - asociacije vprašanj z opisanimi dimenzijami kot jo vidijo strokovnjaki
# - faktorsko matriko
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 23 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.3. Merske karakteristike </div>
# </div>
#
#
# # ■ Zanesljivost
#
# #### Def.: Zanesljivost se nanaša na konsistentnost mere, to je ali bi isti pojem/pojav ob večkratnem merjenju izmerila dovolj podobno.
#
#
# #### Vrste zanesljivosti
# 1. Zanesljivost v času - zanesljivost test-retest: ali večkratno testiranje da podobne rezultate (_ni uporabno za primer dvogovora z Alexo_)
# 2. Notranja konsistentost: ali so odgoovri med vprašanji dovolj povezani (_bistveno za primer dvogovora z Alexo_ - glejte spodaj)
# 3. Konsistentnost med raziskavami (raziskovalci) (_ni uporabno za primer dvogovora z Alexo_)
#
#
# #### Ad 2: Notranja konsistentost - metoda paralelnih oblik (angl. split half)
#
# Odgovori na vprašanje **Ali so odgovori/podatki stabilni?**
#
# ##### Potek določanja
# $\def\s{{\sigma}}$
# Pri tej metodi za dane podatke:
# 1.Testne osebe naključno razdelimo na dve polovici
# 2. Izračunamo korelacije med njimi $r_{12}$
# 3. Po Spearman-Brownovi formuli izračunamo koeficient zanesljivosti
#    - za privzete enake standardne odklone
#   $$ r_{tt} = \frac{2 r_{12}}{1 + r_{12}} $$
#    - za različne standardne odklone
#   $$ r_{tt} = \frac{4 \s_1 \s_2 r_{12}}{\s_1^2 + \s_2^2 + 2 \s_1 \s_2 r_{12}}, $$
#   kjer sta $\s_1$ in $\s_2$ standardna odklona posameznih podatkov.
#
#
#
# #### Ad 2: Notranja konsistentost - Cronbach alpha
#
# Odgovori na vprašanje **Ali vsa vprašanja/podatki skupaj merijo koherenten pojem?**
#
# Izhodišče je razmerje prave variabilnosti $\sigma_T^2$ in izmerjene variabilnosti $\sigma_T^2 + \sigma_\varepsilon^2$, torej
# $$ \frac{\sigma_T^2}{\sigma_T^2 + \sigma_\varepsilon^2}, $$
# ki jo ocenimo s statističnimi formulami kot je med drugim Cronbachova $\alpha$
#
# Velja za enodimenzionalne podatke, zato za vsako dimenziko posebej.
#
# ##### Potek določanja Cronbachove $\alpha$
# Rezultate (odgovore) na $K$ vprašanj $X_i$ seštejemo v
# $$ Y = X_1 + \cdots + X_K, $$
# izračunamo standardne odklone posameznih rezultatov $\s_{X_i}$ in vsote $Y_{Y}$, ter izračunamo
# $$ \alpha = \frac{K-1}{K} \left(1-\frac{\sum _{i=1}^K\s_{X_i}^2}{\s_Y^2}\right) $$
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 24 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %%
## Measurement characteristics
import numpy as np
import pandas as pd 
import random

# Load data 
post_fn = 'https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/2020-2021_PredPost-vprasalnik(dvogovor)(Responses).csv'
#post_fn = 'https://raw.githubusercontent.com/andrejkk/UPK_DataImgs/master/PostQs_Responses.csv'
data_df = pd.read_csv(post_fn, header=0, sep=';', encoding='utf8').drop([13])


# Selectors 
pre_qs_inds = list(range(5,11))
post_qs_inds = list(range(11,36))


# ==============================================================================================
## Validitiy
# We estimate is OK

# ==============================================================================================
## Reliability

# Parallel forms - inter method reliability: divide test tasks to two parts and corelate anwsers 
# Split half
np.random.shuffle(post_qs_inds)
perm_inds_1, perm_inds_2 = post_qs_inds[0:12], post_qs_inds[12:24] 
anws_1, anws_2 = data_df.iloc[:, perm_inds_1], data_df.iloc[:, perm_inds_2]


# Get correlation coefficient
half1_pd = anws_1.sum(axis=1)
half2_pd = anws_2.sum(axis=1)
corr = np.corrcoef(half1_pd, half2_pd)[0,1]


# ==============================================================================================
print ('====================================================================================')
print ('== For instruments')
# Spearman–Brown prediction formula
# Equal variances
req_tt = 2*corr / (1.0 + corr)
print ('Equal var, r_tt=', req_tt)

# Non-equal variances
sd1, sd2 = np.std(half1_pd), np.std(half2_pd) 
rneq_tt = 4*sd1*sd2*corr / (sd1**2 + sd2**2 +  2*sd1*sd2*corr)
print ('Std 1 = ', sd1)
print ('Std 2 = ', sd2)
print ('Not equal var, r_tt=', rneq_tt)


## ==============================================================
# Internal consistency - Cronbach alpha
# Verifies the instrument as a whole

post_qs_df = data_df.iloc[:, 11:36]
_,K = post_qs_df.shape
X = post_qs_df.sum(axis=1)
ss_X = np.var(X, ddof=1)
ss_Yi = np.var(post_qs_df, ddof=1)
ss_Y = ss_Yi.sum()

Cronb_a = (K/(K-1))*(1.0 - ss_Y/ss_X)
print ('Cronbach Alpha =', Cronb_a)

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;"> Merjenje uporabnikov - instrumenti in konstrukti </div>
# <div style="flex:1;width:50%;text-align:right;"> 1.3. Merske karakteristike </div>
# </div>
#
# ## ■ Zaključek
#
#
# - Stabilno merjenje uporabnikov skozi vprašalnike zahteva razvit instrument in konstrukt
# - ne razvijaj novih konstruktov, uporabi obstoječega (razvoj novih je stvar raziskav, ne uporabe)
# - merske karakteristike so bistvene: če niso izpolnjene, rezultati merjenja niso relevantni
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;"> 25 </div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">
