# %% [markdown]
# <img src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png" style="float: center; width: 100%"/>
#
#
# <p style="margin-bottom:2cm;"></p>
# <center>
# <h1>5. Modeling users</h1>
# <br/><br/>
# <h3>Andrej Košir, Lucami, Fe</h3>
# <h4>Contact: andrej.kosir@fe.uni-lj.si</h4>
# <h4>Zoom https://uni-lj-si.zoom.us/J/8638167479</h4>
# </center>
#
#
# <p style="margin-bottom:2cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">1</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;">5. Modeling users</div>
# <div style="flex:1;width:50%;text-align:right;">Goals</div>
# </div>
#
# ## Goals
#
# - to learn the problem of modeling users
# - to get to know:
# - User segmentation
# - user context
# - Modeling with Markov chains
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">2</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>

# %% [markdown]
# <div style="display:flex;font-weight:bold;font-size:0.9em;">
# <div style="flex:1;width:50%;">5. Modeling users</div>
# <div style="flex:1;width:50%;text-align:right;">Content</div>
# </div>
#
# ## Chapters
#
# ### Modeling users: segmentation
#
#
# #### 1. Segmentation
#
# ■ What is segmentation, why?
#
# ■ What is the tgi segmentation*
#
# ■ TGI targets - what does it offer*
#
# ■ User sectors
#
# ■ Example of result: users segments with descriptions
#
# ■ Conclusions
#
#
# #### 2. Segmentation of mobile communications users
#
#
# ■ Dimensions of Segemt Mobile Communications users
#
# ■ Conceptual tree for users' style of life
#
# ■ Conceptual tree to motivate use
#
# ■ Conceptual tree for the properties of services and products
#
# ■ Performing user research and analysis
#
#
#
#
# ### Modeling users: context
#
# #### 1. Context
#
# ■ Introduction and description of context
#
# ■ Structure of the context
#
# ■ Hierarchy of context*
#
# ■ Stages of considering context
#
# ■ Context factors and context accessibility*
#
# ■ Determination of context - sources of information
#
# ■ Determination of context - algorithms
#
# ■ Determining context - data masses of real use of services
#
#
#
# <p style="margin-bottom:1cm;"></p>
# <div style="width:100%;text-align:right;font-weight:bold;font-size:1.2em;">3</div>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg"/>
